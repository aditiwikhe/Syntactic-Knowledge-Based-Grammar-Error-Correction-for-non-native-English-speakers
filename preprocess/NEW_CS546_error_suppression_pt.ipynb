# %% [markdown]
# # Error Suppression

# %% [markdown]
# ## Part 0: Encoding and processing a file, helper methods, etc

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def encode_file(filename): 
  sentences = []
  annotations = {} 

  idx = -1 
  with open(filename, encoding="latin-1") as f: 
    for line in f.readlines(): 
      if line[0] == 'S':
        """
        changes for removing '\n' and indexing the sentence from the second 
        element
        """
        sentences.append(line.rstrip()[2:]) 
        idx += 1
      elif line[0] == 'A':
        if idx in annotations: 
          annotations[idx].append(line) 
        else: 
          annotations[idx] = [line] 
      else: 
        continue 

  return sentences, annotations

# %%
def encode_errors_only(annotations): 
  errors = {} 
  error_count = 0
  noop_count = 0 
  for idx in annotations.keys(): 
    errors[idx] = [] 
    for annot in annotations[idx]: 
      error = annot.split("|||")[1]
      if error != "noop": 
        error_count += 1
        errors[idx].append(error)
      else:
        noop_count += 1

  return errors, error_count, noop_count

# %%
def get_error_dist(errors, noop_count): 
  error_dist = {} 
  total_count = noop_count
  for idx in errors.keys(): 
    for error in errors[idx]: 
      total_count += 1
      if error not in error_dist: 
        error_dist[error] = 1
      else: 
        error_dist[error] += 1 
  
  for error in error_dist.keys(): 
    error_dist[error] = error_dist[error] * 1.0 / total_count 

  return error_dist

# %%
def get_error_dist_count(errors, noop_count): 
  error_dist = {} 
  total_count = noop_count
  for idx in errors.keys(): 
    for error in errors[idx]: 
      total_count += 1
      if error not in error_dist: 
        error_dist[error] = 1
      else: 
        error_dist[error] += 1 

  return error_dist

# %%
import json

# %%
# Opening JSON file
with open('/content/drive/MyDrive/CS 546 Final Project /CoNLL14 test data evaluation/lang_tags.json') as json_file:
    all_lang_data = json.load(json_file)

# %%
all_lang_data.keys()
# Out:
# dict_keys(['ca', 'ko', 'ru', 'pl', 'pt', 'th', 'es', 'zh', 'it', 'tr', 'fr', 'ja', 'de', 'el', 'sv', 'nl'])

# %%
all_lang_data['ru']
# Out:
# {'M:ADJ': 2,
#  'R:PART': 3,
#  'U:NOUN:POSS': 3,
#  'R:NOUN:INFL': 3,
#  'U:ADJ': 3,
#  'M:NOUN:POSS': 4,
#  'M:PART': 4,
#  'U:PART': 5,
#  'U:VERB:FORM': 5,
#  'U:CONJ': 5,
#  'R:VERB:INFL': 6,
#  'R:CONTR': 6,
#  'M:ADV': 7,
#  'R:CONJ': 8,
#  'U:CONTR': 9,
#  'R:NOUN:POSS': 9,
#  'U:PRON': 10,
#  'M:VERB:FORM': 11,
#  'U:VERB': 12,
#  'M:NOUN': 13,
#  'U:OTHER': 13,
#  'U:NOUN': 15,
#  'M:CONJ': 15,
#  'U:ADV': 16,
#  'M:PRON': 28,
#  'U:VERB:TENSE': 29,
#  'R:VERB:SVA': 30,
#  'M:VERB': 39,
#  'R:ADV': 45,
#  'M:VERB:TENSE': 45,
#  'M:OTHER': 45,
#  'R:ADJ': 53,
#  'M:PREP': 53,
#  'R:PRON': 58,
#  'R:MORPH': 60,
#  'U:PREP': 66,
#  'R:PUNCT': 71,
#  'R:WO': 73,
#  'U:DET': 74,
#  'R:ORTH': 77,
#  'R:NOUN:NUM': 79,
#  'R:VERB:FORM': 82,
#  'U:PUNCT': 87,
#  'UNK': 91,
#  'R:DET': 98,
#  'R:NOUN': 101,
#  'R:VERB:TENSE': 107,
#  'M:PUNCT': 126,
#  'R:PREP': 174,
#  'R:VERB': 183,
#  'R:OTHER': 278,
#  'M:DET': 297,
#  'R:SPELL': 477,
#  'noop': 715}

# %%
lang_probs = {}
for x in all_lang_data.keys():
  lang_probs[x] = {}
  count = 0
  for y in all_lang_data[x].keys():
    count = count + all_lang_data[x][y]
  for y in all_lang_data[x].keys():
    lang_probs[x][y] = all_lang_data[x][y] / count

# %%
goal_error_dist = lang_probs['ru']

# %%
goal_error_dist
# Out:
# {'M:ADJ': 0.0005091649694501018,
#  'R:PART': 0.0007637474541751527,
#  'U:NOUN:POSS': 0.0007637474541751527,
#  'R:NOUN:INFL': 0.0007637474541751527,
#  'U:ADJ': 0.0007637474541751527,
#  'M:NOUN:POSS': 0.0010183299389002036,
#  'M:PART': 0.0010183299389002036,
#  'U:PART': 0.0012729124236252546,
#  'U:VERB:FORM': 0.0012729124236252546,
#  'U:CONJ': 0.0012729124236252546,
#  'R:VERB:INFL': 0.0015274949083503055,
#  'R:CONTR': 0.0015274949083503055,
#  'M:ADV': 0.0017820773930753565,
#  'R:CONJ': 0.002036659877800407,
#  'U:CONTR': 0.002291242362525458,
#  'R:NOUN:POSS': 0.002291242362525458,
#  'U:PRON': 0.0025458248472505093,
#  'M:VERB:FORM': 0.00280040733197556,
#  'U:VERB': 0.003054989816700611,
#  'M:NOUN': 0.003309572301425662,
#  'U:OTHER': 0.003309572301425662,
#  'U:NOUN': 0.0038187372708757637,
#  'M:CONJ': 0.0038187372708757637,
#  'U:ADV': 0.004073319755600814,
#  'M:PRON': 0.007128309572301426,
#  'U:VERB:TENSE': 0.007382892057026477,
#  'R:VERB:SVA': 0.007637474541751527,
#  'M:VERB': 0.009928716904276986,
#  'R:ADV': 0.011456211812627291,
#  'M:VERB:TENSE': 0.011456211812627291,
#  'M:OTHER': 0.011456211812627291,
#  'R:ADJ': 0.0134928716904277,
#  'M:PREP': 0.0134928716904277,
#  'R:PRON': 0.014765784114052953,
#  'R:MORPH': 0.015274949083503055,
#  'U:PREP': 0.01680244399185336,
#  'R:PUNCT': 0.018075356415478614,
#  'R:WO': 0.018584521384928717,
#  'U:DET': 0.01883910386965377,
#  'R:ORTH': 0.01960285132382892,
#  'R:NOUN:NUM': 0.020112016293279023,
#  'R:VERB:FORM': 0.020875763747454174,
#  'U:PUNCT': 0.02214867617107943,
#  'UNK': 0.023167006109979633,
#  'R:DET': 0.02494908350305499,
#  'R:NOUN': 0.02571283095723014,
#  'R:VERB:TENSE': 0.027240325865580447,
#  'M:PUNCT': 0.03207739307535642,
#  'R:PREP': 0.04429735234215886,
#  'R:VERB': 0.046588594704684315,
#  'R:OTHER': 0.07077393075356415,
#  'M:DET': 0.07561099796334013,
#  'R:SPELL': 0.12143584521384929,
#  'noop': 0.1820264765784114}

# %%
filepath = "/content/drive/MyDrive/CS 546 Final Project /CoNLL14 test data evaluation/train_gec.m2"

# %% [markdown]
# ## Part 1: Identify what errors need to be fixed

# %%
# Using the same m2 file as if that's the one I need to supress errors in. proof of concept basically 
sentences, annotations = encode_file(filepath)
errors_by_sentence, error_count, noop_count= encode_errors_only(annotations)
error_dist_count = get_error_dist_count(errors_by_sentence, noop_count)

# %%
import math

# %%
del goal_error_dist['noop']

# %%
print(error_count)
# Out:
# 62958

# %%
goal_error_dist_count = {} 
for error in goal_error_dist.keys(): 
  goal_error_dist_count[error] = math.ceil(goal_error_dist[error] * (error_count + noop_count))

# %%
goal_error_dist_count
# Out:
# {'M:ADJ': 38,
#  'R:PART': 57,
#  'U:NOUN:POSS': 57,
#  'R:NOUN:INFL': 57,
#  'U:ADJ': 57,
#  'M:NOUN:POSS': 76,
#  'M:PART': 76,
#  'U:PART': 95,
#  'U:VERB:FORM': 95,
#  'U:CONJ': 95,
#  'R:VERB:INFL': 114,
#  'R:CONTR': 114,
#  'M:ADV': 133,
#  'R:CONJ': 152,
#  'U:CONTR': 171,
#  'R:NOUN:POSS': 171,
#  'U:PRON': 190,
#  'M:VERB:FORM': 209,
#  'U:VERB': 228,
#  'M:NOUN': 247,
#  'U:OTHER': 247,
#  'U:NOUN': 285,
#  'M:CONJ': 285,
#  'U:ADV': 304,
#  'M:PRON': 532,
#  'U:VERB:TENSE': 551,
#  'R:VERB:SVA': 570,
#  'M:VERB': 740,
#  'R:ADV': 854,
#  'M:VERB:TENSE': 854,
#  'M:OTHER': 854,
#  'R:ADJ': 1006,
#  'M:PREP': 1006,
#  'R:PRON': 1101,
#  'R:MORPH': 1139,
#  'U:PREP': 1253,
#  'R:PUNCT': 1347,
#  'R:WO': 1385,
#  'U:DET': 1404,
#  'R:ORTH': 1461,
#  'R:NOUN:NUM': 1499,
#  'R:VERB:FORM': 1556,
#  'U:PUNCT': 1651,
#  'UNK': 1727,
#  'R:DET': 1860,
#  'R:NOUN': 1917,
#  'R:VERB:TENSE': 2030,
#  'M:PUNCT': 2391,
#  'R:PREP': 3302,
#  'R:VERB': 3472,
#  'R:OTHER': 5275,
#  'M:DET': 5635,
#  'R:SPELL': 9050}

# %%
new_dict = {}
for k,v in errors_by_sentence.items():
    for x in v:
        new_dict.setdefault(x,[]).append(k)

# %%
from random import sample

# %%
def errors_to_supress(goal_error_dist_count, error_dist_count, new_dict):
  new_dict_1 = {}
  for x in error_dist_count.keys():
    new_dict_1[x[1:-1]] = error_dist_count[x]

  new_dict_2 = {}
  for x in new_dict.keys():
    new_dict_2[x[1:-1]] = new_dict[x]


  error_dict = {}
  for x in goal_error_dist_count.keys():
    #print(x)
    #print(new_dict.keys())
    if x in new_dict_1.keys():
      count_goal = goal_error_dist_count[x]
      count_current = new_dict_1[x]
      #print(count_goal, count_current)
      if count_current > count_goal:
        error_dict[x] = count_current - count_goal
  print(error_dict)

  print(new_dict)
  error_dict_idx = {}
  for x in error_dict:
    error_dict_idx[x] = sample(new_dict_2[x],error_dict[x])
  print(error_dict_idx)


  idx_error = {}
  for k,v in error_dict_idx.items():
    for x in v:
      idx_error.setdefault(x,[]).append(k)
  print(idx_error)

  print(errors_by_sentence)
  for z in errors_by_sentence.keys():
    list_errors = errors_by_sentence[z]
    #print(list_errors)
    new_list_err = []
    for g in list_errors:
      new_list_err.append(g[1:-1])
    errors_by_sentence[z] = new_list_err
    #print(errors_by_sentence[z])

  idx_error_ann_idx = {}
  for x in idx_error.keys():
    idx_error_ann_idx[x] = []
    err_cat_count = {}
    for y in idx_error[x]:
      if y in err_cat_count.keys():
        err_cat_count[y] += 1
      else:
        err_cat_count[y] = 1
    #print(err_cat_count)
    for z in err_cat_count.keys():
      indices = [i for i, j in enumerate(errors_by_sentence[x]) if j == z]
      idx_error_ann_idx[x].extend(indices[:err_cat_count[z]])
  print(idx_error_ann_idx)

  for x in idx_error_ann_idx.keys():
    idx_error_ann_idx[x].sort()
  print(idx_error_ann_idx)
  return idx_error_ann_idx

# %%
idx_error_ann_idx = errors_to_supress(goal_error_dist_count, error_dist_count, new_dict)
# Out:
# {'M:ADJ': 120, 'R:PART': 336, 'U:NOUN:POSS': 12, 'U:ADJ': 50, 'M:NOUN:POSS': 115, 'M:PART': 21, 'R:CONTR': 48, 'M:ADV': 227, 'U:PRON': 59, 'U:VERB': 85, 'M:NOUN': 210, 'U:OTHER': 546, 'U:NOUN': 108, 'U:ADV': 74, 'M:PRON': 215, 'R:VERB:SVA': 797, 'M:OTHER': 434, 'M:PREP': 267, 'R:MORPH': 420, 'R:PUNCT': 917, 'U:DET': 1061, 'R:ORTH': 1327, 'R:NOUN:NUM': 1004, 'R:VERB:FORM': 357, 'R:NOUN': 455, 'R:VERB:TENSE': 994, 'M:PUNCT': 5495, 'R:PREP': 867}
# {' M:PUNCT ': [0, 1, 7, 10, 16, 19, 19, 20, 20, 20, 21, 51, 65, 65, 71, 73, 85, 88, 88, 89, 96, 97, 97, 98, 104, 113, 113, 114, 114, 115, 116, 117, 118, 119, 120, 120, 127, 130, 130, 130, 130, 130, 130, 136, 136, 139, 139, 143, 148, 149, 150, 157, 162, 173, 173, 176, 178, 195, 198, 203, 213, 219, 219, 219, 219, 219, 219, 220, 220, 220, 221, 226, 237, 259, 260, 262, 262, 262, 270, 271, 274, 275, 280, 290, 291, 292, 297, 299, 300, 311, 319, 320, 320, 320, 320, 321, 325, 325, 326, 331, 331, 333, 340, 345, 358, 358, 360, 360, 362, 363, 363, 378, 379, 380, 382, 383, 384, 385, 393, 397, 398, 402, 402, 404, 405, 408, 410, 415, 416, 417, 420, 421, 421, 421, 423, 423, 423, 423, 423, 423, 432, 434, 438, 438, 440, 443, 457, 459, 467, 468, 468, 470, 475, 477, 478, 480, 480, 498, 498, 503, 503, 507, 508, 509, 515, 515, 515, 515, 525, 546, 550, 552, 557, 573, 575, 583, 585, 587, 587, 587, 588, 588, 593, 601, 609, 609, 612, 614, 614, 614, 615, 617, 627, 638, 638, 643, 644, 649, 649, 650, 651, 653, 669, 669, 672, 707, 714, 716, 716, 716, 719, 720, 720, 724, 727, 733, 735, 737, 739, 753, 753, 756, 759, 771, 793, 793, 794, 800, 801, 801, 803, 810, 812, 812, 812, 813, 813, 815, 832, 838, 839, 839, 841, 842, 843, 843, 843, 859, 874, 876, 876, 877, 878, 891, 895, 907, 908, 908, 910, 911, 913, 913, 914, 926, 930, 946, 946, 946, 946, 946, 947, 947, 947, 947, 948, 950, 956, 957, 962, 966, 971, 971, 981, 984, 996, 999, 999, 1000, 1000, 1000, 1004, 1006, 1014, 1024, 1027, 1029, 1032, 1032, 1046, 1047, 1062, 1063, 1067, 1076, 1078, 1082, 1093, 1094, 1095, 1102, 1102, 1109, 1110, 1111, 1114, 1123, 1128, 1129, 1130, 1134, 1136, 1136, 1138, 1140, 1141, 1141, 1141, 1141, 1149, 1152, 1155, 1155, 1163, 1163, 1165, 1165, 1166, 1171, 1172, 1173, 1180, 1182, 1182, 1184, 1186, 1188, 1189, 1193, 1197, 1197, 1213, 1217, 1221, 1221, 1229, 1234, 1237, 1249, 1252, 1253, 1253, 1253, 1253, 1257, 1261, 1261, 1262, 1262, 1262, 1265, 1267, 1267, 1269, 1270, 1287, 1290, 1295, 1298, 1299, 1299, 1299, 1308, 1312, 1314, 1318, 1323, 1323, 1324, 1325, 1339, 1348, 1349, 1354, 1354, 1355, 1365, 1377, 1384, 1390, 1392, 1405, 1405, 1407, 1408, 1413, 1424, 1424, 1425, 1426, 1427, 1437, 1458, 1461, 1464, 1466, 1467, 1470, 1476, 1479, 1479, 1481, 1486, 1487, 1487, 1489, 1490, 1491, 1494, 1495, 1511, 1511, 1513, 1514, 1514, 1515, 1515, 1516, 1517, 1517, 1517, 1523, 1529, 1529, 1532, 1570, 1579, 1580, 1586, 1591, 1603, 1604, 1607, 1607, 1609, 1634, 1636, 1636, 1640, 1643, 1650, 1652, 1652, 1657, 1659, 1659, 1661, 1663, 1664, 1690, 1697, 1715, 1735, 1737, 1755, 1761, 1762, 1764, 1765, 1768, 1768, 1769, 1769, 1769, 1770, 1775, 1779, 1781, 1782, 1782, 1783, 1805, 1806, 1809, 1812, 1813, 1813, 1814, 1818, 1819, 1822, 1828, 1830, 1832, 1833, 1838, 1839, 1839, 1850, 1854, 1859, 1863, 1871, 1871, 1875, 1875, 1878, 1879, 1879, 1881, 1881, 1883, 1883, 1906, 1911, 1912, 1912, 1915, 1933, 1937, 1938, 1939, 1939, 1940, 1942, 1948, 1951, 1953, 1953, 1953, 1957, 1957, 1957, 1957, 1957, 1957, 1957, 1957, 1958, 1958, 1958, 1958, 1967, 1969, 1979, 1980, 1981, 1983, 1992, 2000, 2001, 2013, 2014, 2019, 2038, 2039, 2040, 2040, 2046, 2052, 2052, 2053, 2061, 2061, 2061, 2061, 2061, 2061, 2062, 2062, 2071, 2071, 2071, 2073, 2073, 2073, 2074, 2074, 2075, 2079, 2079, 2079, 2079, 2080, 2081, 2088, 2093, 2096, 2108, 2110, 2111, 2113, 2115, 2120, 2122, 2131, 2142, 2142, 2175, 2181, 2182, 2199, 2202, 2221, 2222, 2235, 2243, 2243, 2247, 2251, 2256, 2263, 2263, 2263, 2263, 2265, 2266, 2266, 2267, 2286, 2286, 2287, 2288, 2289, 2290, 2290, 2295, 2304, 2317, 2319, 2321, 2324, 2328, 2333, 2336, 2347, 2350, 2351, 2369, 2369, 2376, 2399, 2399, 2399, 2405, 2405, 2438, 2439, 2449, 2449, 2451, 2461, 2461, 2462, 2462, 2463, 2463, 2483, 2498, 2499, 2501, 2501, 2508, 2510, 2512, 2521, 2521, 2528, 2532, 2544, 2545, 2546, 2547, 2551, 2552, 2555, 2575, 2575, 2585, 2587, 2588, 2589, 2589, 2590, 2605, 2614, 2614, 2617, 2617, 2622, 2624, 2624, 2625, 2648, 2674, 2687, 2689, 2692, 2692, 2692, 2692, 2692, 2693, 2693, 2693, 2694, 2695, 269 ...
# {'M:ADJ': [8926, 27287, 10132, 8690, 984, 5713, 2858, 3227, 654, 16425, 11145, 10580, 4647, 8666, 3233, 6619, 4648, 8958, 2012, 2210, 33714, 15811, 2508, 4732, 31049, 13443, 4974, 6846, 19955, 6621, 33931, 4054, 3109, 29661, 6338, 9325, 2522, 21099, 16183, 15902, 30519, 7411, 25229, 5538, 31224, 3808, 11020, 614, 22522, 33282, 9904, 3966, 12717, 6822, 30808, 20022, 13403, 23657, 26202, 9552, 22135, 936, 26201, 20414, 7403, 29826, 9739, 10445, 9543, 23275, 22375, 19722, 6101, 4127, 9813, 15403, 23242, 7087, 5081, 13410, 22349, 10374, 537, 14729, 23301, 5081, 3151, 8186, 28578, 7704, 17521, 10003, 24180, 13645, 7705, 416, 3792, 28106, 21039, 17642, 2335, 17138, 12362, 5402, 8094, 24691, 984, 3564, 12220, 5226, 8563, 27527, 5248, 16461, 2653, 31292, 10312, 25557, 16176, 14242], 'R:PART': [26605, 19718, 28157, 4170, 23388, 29992, 11821, 20465, 10332, 6171, 3692, 12232, 24164, 8106, 6254, 6988, 24727, 3204, 16170, 20589, 22699, 141, 21360, 3500, 19521, 458, 16801, 22080, 15298, 19229, 10681, 31940, 25441, 28510, 10061, 9240, 5530, 33056, 13105, 5739, 18128, 28275, 32690, 27194, 11419, 10658, 7148, 3091, 7089, 23414, 7147, 17418, 17239, 4986, 6764, 13918, 10088, 4105, 4553, 695, 6906, 18872, 5538, 33893, 17793, 15015, 6910, 18932, 9455, 8844, 20067, 17323, 9762, 30972, 18132, 26597, 16045, 18974, 31049, 24246, 20036, 17427, 6135, 4649, 10297, 16933, 8687, 4104, 2004, 20437, 6323, 13292, 20637, 10157, 10278, 4218, 10379, 13134, 29439, 34093, 29052, 7138, 17787, 31814, 29438, 20653, 20166, 5813, 5143, 23384, 14663, 18608, 9609, 19930, 8643, 17272, 9179, 3900, 7915, 1355, 24834, 8925, 10076, 22453, 10063, 29315, 14340, 20769, 23244, 17421, 6688, 12662, 30902, 4345, 10491, 5988, 3350, 11397, 12385, 17363, 16695, 7738, 10054, 31083, 12517, 10908, 23030, 22429, 13287, 4217, 1129, 8868, 5413, 13494, 296, 25254, 20121, 17811, 23562, 945, 19194, 17430, 14439, 15021, 18132, 1389, 17573, 24133, 15095, 21394, 21113, 6185, 19167, 3683, 4026, 30693, 7569, 7798, 7954, 27849, 15073, 28694, 13894, 1618, 9149, 8616, 33546, 14440, 21761, 5081, 7136, 4918, 14305, 7798, 13885, 4417, 17289, 1536, 9767, 3492, 14147, 20890, 10068, 32258, 13749, 32315, 20422, 4776, 22460, 24850, 6174, 23276, 31533, 7377, 21563, 8762, 1345, 20286, 16577, 16804, 6767, 14183, 29775, 2248, 8645, 3547, 34274, 9312, 1177, 8571, 25619, 16276, 25452, 9076, 10061, 8107, 30897, 1580, 29384, 5731, 33055, 5318, 24033, 8272, 30057, 5663, 9783, 2469, 10564, 3127, 14614, 811, 7502, 24523, 8842, 22092, 29953, 27282, 5058, 7423, 21367, 6913, 16045, 6576, 25124, 21923, 10563, 33152, 13311, 956, 19004, 31355, 22811, 22993, 6651, 14758, 2865, 18129, 7142, 16816, 8687, 11216, 5747, 5662, 19740, 3818, 25375, 29497, 8766, 9446, 2417, 968, 22765, 32640, 10872, 16476, 27985, 29089, 11120, 20741, 21734, 5528, 8417, 5707, 14564, 9627, 3557, 16103, 6967, 21849, 667, 9980, 12724, 24152, 23430, 17346, 2735, 8617, 31937, 28404, 13432, 26728, 6754, 33194, 253, 31808, 4774, 3937, 2977, 29950, 12369, 20670, 732, 14487, 19697, 1224], 'U:NOUN:POSS': [23936, 17485, 7259, 5826, 5541, 32873, 14043, 4305, 19608, 12022, 10826, 14651], 'U:ADJ': [6099, 29429, 16733, 10215, 22246, 12341, 4983, 15366, 23428, 9617, 20667, 6164, 16162, 17897, 21161, 23346, 5378, 12179, 33919, 33914, 1480, 29131, 2856, 18238, 11300, 20200, 18422, 20867, 15509, 8569, 22547, 31480, 5847, 24637, 3844, 4855, 11849, 6914, 11170, 13513, 30522, 23252, 13335, 26609, 3039, 7787, 32473, 18257, 13807, 34161], 'M:NOUN:POSS': [20493, 27549, 27148, 10381, 23261, 9480, 16731, 31949, 2107, 27149, 3390, 10908, 9257, 25463, 22854, 17945, 7002, 3159, 26199, 20358, 30158, 17288, 8408, 31189, 33089, 18000, 18129, 7014, 27341, 33099, 11339, 7637, 6698, 28660, 8842, 20064, 9510, 28491, 358, 3433, 10382, 7167, 22846, 33089, 31649, 24626, 23705, 2082, 30804, 9136, 9131, 21869, 14571, 19020, 15122, 9437, 14570, 3433, 9254, 30809, 7246, 14545, 17689, 27689, 3959, 33534, 18010, 23262, 33099, 9052, 18007, 16175, 13856, 22797, 2962, 30326, 23908, 28126, 17718, 21725, ...
# {8926: ['M:ADJ', 'U:OTHER', 'R:ORTH'], 27287: ['M:ADJ'], 10132: ['M:ADJ', 'M:PUNCT'], 8690: ['M:ADJ'], 984: ['M:ADJ', 'M:ADJ', 'M:PUNCT'], 5713: ['M:ADJ'], 2858: ['M:ADJ', 'R:VERB:SVA', 'R:PUNCT', 'R:PUNCT', 'R:NOUN:NUM', 'R:NOUN', 'R:VERB:TENSE', 'M:PUNCT', 'M:PUNCT'], 3227: ['M:ADJ', 'U:OTHER', 'M:OTHER', 'R:VERB:TENSE', 'M:PUNCT'], 654: ['M:ADJ', 'R:NOUN:NUM'], 16425: ['M:ADJ', 'R:VERB:TENSE', 'M:PUNCT'], 11145: ['M:ADJ'], 10580: ['M:ADJ', 'U:OTHER', 'M:PREP'], 4647: ['M:ADJ', 'U:VERB', 'R:VERB:SVA', 'U:DET', 'R:ORTH', 'R:ORTH', 'R:NOUN:NUM'], 8666: ['M:ADJ', 'R:VERB:FORM', 'R:VERB:TENSE', 'M:PUNCT'], 3233: ['M:ADJ', 'R:PUNCT'], 6619: ['M:ADJ'], 4648: ['M:ADJ', 'U:OTHER', 'R:ORTH', 'M:PUNCT'], 8958: ['M:ADJ', 'M:PUNCT'], 2012: ['M:ADJ'], 2210: ['M:ADJ', 'R:ORTH', 'R:NOUN:NUM'], 33714: ['M:ADJ'], 15811: ['M:ADJ', 'R:ORTH', 'R:NOUN:NUM'], 2508: ['M:ADJ', 'M:PUNCT'], 4732: ['M:ADJ', 'U:OTHER', 'R:PUNCT'], 31049: ['M:ADJ', 'R:PART', 'R:VERB:TENSE', 'M:PUNCT', 'M:PUNCT'], 13443: ['M:ADJ', 'M:PREP', 'M:PUNCT'], 4974: ['M:ADJ', 'R:NOUN:NUM', 'R:PREP'], 6846: ['M:ADJ', 'R:VERB:TENSE'], 19955: ['M:ADJ'], 6621: ['M:ADJ'], 33931: ['M:ADJ', 'U:DET', 'R:PREP', 'R:PREP'], 4054: ['M:ADJ', 'R:PUNCT', 'U:DET', 'R:VERB:TENSE'], 3109: ['M:ADJ'], 29661: ['M:ADJ'], 6338: ['M:ADJ'], 9325: ['M:ADJ'], 2522: ['M:ADJ'], 21099: ['M:ADJ'], 16183: ['M:ADJ'], 15902: ['M:ADJ'], 30519: ['M:ADJ', 'R:PUNCT', 'R:ORTH'], 7411: ['M:ADJ'], 25229: ['M:ADJ'], 5538: ['M:ADJ', 'R:PART', 'R:VERB:SVA', 'R:ORTH', 'R:NOUN:NUM', 'M:PUNCT', 'R:PREP'], 31224: ['M:ADJ'], 3808: ['M:ADJ'], 11020: ['M:ADJ', 'U:VERB'], 614: ['M:ADJ', 'U:OTHER', 'M:PUNCT', 'M:PUNCT', 'M:PUNCT'], 22522: ['M:ADJ'], 33282: ['M:ADJ', 'R:NOUN'], 9904: ['M:ADJ'], 3966: ['M:ADJ', 'R:ORTH', 'M:PUNCT'], 12717: ['M:ADJ', 'M:PREP', 'M:PUNCT'], 6822: ['M:ADJ'], 30808: ['M:ADJ'], 20022: ['M:ADJ'], 13403: ['M:ADJ', 'R:ORTH', 'R:VERB:TENSE'], 23657: ['M:ADJ', 'M:PUNCT'], 26202: ['M:ADJ'], 9552: ['M:ADJ'], 22135: ['M:ADJ', 'M:ADV', 'M:PREP', 'U:DET', 'R:VERB:TENSE', 'R:PREP'], 936: ['M:ADJ'], 26201: ['M:ADJ'], 20414: ['M:ADJ'], 7403: ['M:ADJ', 'R:PREP'], 29826: ['M:ADJ', 'M:PREP'], 9739: ['M:ADJ', 'R:PUNCT', 'R:NOUN:NUM'], 10445: ['M:ADJ'], 9543: ['M:ADJ', 'U:VERB', 'U:OTHER', 'R:VERB:SVA', 'R:VERB:SVA', 'R:ORTH', 'R:ORTH', 'R:ORTH', 'M:PUNCT'], 23275: ['M:ADJ', 'R:MORPH'], 22375: ['M:ADJ', 'M:PUNCT'], 19722: ['M:ADJ'], 6101: ['M:ADJ', 'R:ORTH', 'M:PUNCT'], 4127: ['M:ADJ', 'U:DET', 'R:ORTH', 'M:PUNCT', 'M:PUNCT', 'M:PUNCT'], 9813: ['M:ADJ', 'R:PUNCT', 'R:ORTH', 'M:PUNCT'], 15403: ['M:ADJ', 'R:PREP'], 23242: ['M:ADJ'], 7087: ['M:ADJ'], 5081: ['M:ADJ', 'M:ADJ', 'R:PART', 'U:OTHER', 'R:PUNCT', 'R:ORTH', 'R:ORTH', 'M:PUNCT', 'M:PUNCT'], 13410: ['M:ADJ'], 22349: ['M:ADJ', 'M:PUNCT'], 10374: ['M:ADJ'], 537: ['M:ADJ'], 14729: ['M:ADJ', 'M:PUNCT'], 23301: ['M:ADJ', 'R:PUNCT', 'R:NOUN:NUM', 'R:NOUN'], 3151: ['M:ADJ', 'U:NOUN', 'U:DET', 'R:VERB:TENSE'], 8186: ['M:ADJ', 'M:PUNCT'], 28578: ['M:ADJ'], 7704: ['M:ADJ', 'U:DET'], 17521: ['M:ADJ', 'R:NOUN'], 10003: ['M:ADJ', 'U:DET'], 24180: ['M:ADJ'], 13645: ['M:ADJ'], 7705: ['M:ADJ', 'U:DET', 'R:VERB:TENSE'], 416: ['M:ADJ'], 3792: ['M:ADJ'], 28106: ['M:ADJ'], 21039: ['M:ADJ'], 17642: ['M:ADJ', 'M:PUNCT'], 2335: ['M:ADJ', 'U:DET', 'R:VERB:FORM'], 17138: ['M:ADJ'], 12362: ['M:ADJ'], 5402: ['M:ADJ'], 8094: ['M:ADJ'], 24691: ['M:ADJ'], 3564: ['M:ADJ', 'R:VERB:SVA', 'M:PUNCT', 'M:PUNCT'], 12220: ['M:ADJ', 'U:OTHER'], 5226: ['M:ADJ', 'U:DET', 'R:VERB:TENSE', 'M:PUNCT'], 8563: ['M:ADJ', 'R:VERB:SVA', 'R:VERB:SVA', 'M:OTHER'], 27527: ['M:ADJ'], 5248: ['M:ADJ', 'M:PUNCT', 'M:PUNCT'], 16461: ['M:ADJ'], 2653: ['M:ADJ'], 31292: ['M:ADJ'], 10312: ['M:ADJ'], 25557: ['M:ADJ'], 16176: ['M:ADJ', 'R:MORPH'], 14242: ['M:ADJ'], 26605: ['R:PART'], 19718: ['R:PART', 'R:VERB:TENSE'], 28157: ['R:PART'], 4170: ['R:PART', 'R:ORTH', 'R:NOUN:NUM', 'R:VERB:TENSE'], 23388: ['R:PART', 'R:PUNCT', 'M:PUNCT'], 29992: ['R:PART', 'U:DET'], 11821: ['R:PART'], 20465: ['R:PART', 'R:VERB:FORM'], 10332: ['R:PART',  ...
# {0: [' M:PUNCT ', ' R:MORPH '], 1: [' M:PUNCT ', ' M:PREP '], 2: [' R:PREP ', ' U:PREP '], 3: [' R:SPELL '], 4: [' R:PREP '], 5: [' R:VERB:SVA ', ' R:SPELL ', ' R:NOUN:NUM ', ' R:NOUN ', ' R:NOUN '], 6: [' M:PREP '], 7: [' R:VERB:SVA ', ' R:VERB:SVA ', ' U:DET ', ' M:PUNCT ', ' R:WO ', ' R:VERB ', ' R:VERB ', ' R:MORPH ', ' R:PREP ', ' U:DET '], 8: [], 9: [' M:DET ', ' R:NOUN:NUM '], 10: [' M:PUNCT ', ' R:OTHER ', ' M:OTHER ', ' R:PUNCT ', ' R:ORTH '], 11: [' R:ORTH ', ' R:PREP '], 12: [], 13: [' M:CONJ '], 14: [' R:VERB ', ' U:PREP ', ' R:NOUN ', ' R:PUNCT '], 15: [' M:DET ', ' M:DET ', ' R:ORTH '], 16: [' M:DET ', ' R:ORTH ', ' M:PUNCT ', ' R:VERB:SVA '], 17: [], 18: [' R:ADV ', ' R:OTHER ', ' R:PREP ', ' R:NOUN ', ' R:ADJ ', ' R:NOUN:NUM ', ' R:OTHER '], 19: [' M:OTHER ', ' M:PUNCT ', ' M:PUNCT ', ' R:NOUN ', ' R:OTHER ', ' R:OTHER '], 20: [' M:VERB ', ' M:PUNCT ', ' R:OTHER ', ' M:PUNCT ', ' R:WO ', ' M:PUNCT ', ' R:VERB '], 21: [' M:PUNCT ', ' R:WO ', ' R:PREP ', ' R:NOUN:NUM ', ' R:PREP ', ' M:DET ', ' R:NOUN:NUM ', ' R:PUNCT ', ' R:VERB ', ' U:PREP ', ' R:OTHER ', ' R:NOUN ', ' R:NOUN:NUM ', ' R:SPELL '], 22: [' R:NOUN:NUM ', ' M:OTHER '], 23: [], 24: [' R:ADV '], 25: [' U:PREP ', ' R:VERB '], 26: [], 27: [' R:PREP ', ' R:NOUN ', ' R:VERB:TENSE ', ' M:DET '], 28: [], 29: [' R:NOUN '], 30: [' M:PREP '], 31: [], 32: [], 33: [' R:VERB ', ' R:OTHER '], 34: [' R:VERB:TENSE '], 35: [' R:MORPH ', ' M:PRON '], 36: [' R:OTHER '], 37: [], 38: [' R:SPELL ', ' R:OTHER ', ' R:ADJ ', ' M:PREP '], 39: [' R:OTHER '], 40: [' R:VERB '], 41: [' R:VERB:TENSE '], 42: [' R:OTHER ', ' U:PUNCT '], 43: [' R:VERB '], 44: [' R:OTHER '], 45: [' R:OTHER '], 46: [], 47: [' R:VERB:TENSE '], 48: [' R:OTHER '], 49: [], 50: [], 51: [' M:PUNCT ', ' R:PRON ', ' R:VERB:SVA ', ' R:OTHER '], 52: [], 53: [], 54: [' U:VERB ', ' M:VERB '], 55: [' U:PUNCT ', ' M:DET '], 56: [], 57: [], 58: [' R:OTHER ', ' M:CONJ ', ' R:ADV ', ' R:PREP '], 59: [], 60: [], 61: [' R:SPELL '], 62: [], 63: [' U:OTHER ', ' U:DET '], 64: [' M:OTHER ', ' R:PREP ', ' U:DET '], 65: [' M:PUNCT ', ' R:SPELL ', ' R:PREP ', ' M:PUNCT ', ' R:OTHER ', ' R:DET '], 66: [], 67: [], 68: [], 69: [], 70: [' R:SPELL '], 71: [' M:PUNCT '], 72: [], 73: [' M:PUNCT ', ' M:NOUN '], 74: [], 75: [], 76: [' R:PRON '], 77: [], 78: [], 79: [' M:OTHER ', ' R:VERB ', ' U:OTHER '], 80: [' R:ADV '], 81: [' U:ADV ', ' R:OTHER '], 82: [' R:VERB:TENSE ', ' M:PART '], 83: [], 84: [], 85: [' R:PREP ', ' M:PUNCT ', ' R:NOUN ', ' M:NOUN '], 86: [], 87: [], 88: [' M:PUNCT ', ' R:SPELL ', ' R:VERB ', ' R:VERB ', ' R:SPELL ', ' R:ORTH ', ' R:SPELL ', ' M:PUNCT '], 89: [' R:PREP ', ' M:PUNCT '], 90: [], 91: [' U:VERB ', ' M:VERB ', ' R:OTHER ', ' R:SPELL ', ' U:PREP '], 92: [' R:PRON ', ' M:ADV '], 93: [' R:VERB:TENSE ', ' R:OTHER '], 94: [], 95: [' R:VERB:TENSE ', ' R:VERB:TENSE ', ' R:MORPH '], 96: [' M:PUNCT ', ' R:VERB:TENSE '], 97: [' M:PUNCT ', ' R:VERB:TENSE ', ' M:PUNCT '], 98: [' M:PUNCT ', ' R:SPELL '], 99: [' R:ORTH ', ' R:VERB:TENSE '], 100: [], 101: [], 102: [], 103: [], 104: [' M:PUNCT ', ' U:PUNCT ', ' R:OTHER ', ' R:PUNCT ', ' R:PRON '], 105: [' M:OTHER ', ' U:CONTR ', ' R:NOUN '], 106: [' M:DET ', ' R:PUNCT ', ' R:NOUN ', ' R:OTHER ', ' R:PUNCT ', ' R:DET '], 107: [' R:OTHER '], 108: [], 109: [' R:VERB:SVA '], 110: [' R:PUNCT ', ' M:DET ', ' R:PRON '], 111: [], 112: [' R:VERB:SVA '], 113: [' R:OTHER ', ' M:PUNCT ', ' M:PUNCT ', ' R:SPELL '], 114: [' R:OTHER ', ' R:NOUN ', ' R:VERB:FORM ', ' M:PUNCT ', ' M:PUNCT ', ' R:WO ', ' R:PUNCT '], 115: [' U:DET ', ' U:NOUN ', ' U:DET ', ' R:SPELL ', ' R:VERB:SVA ', ' M:PUNCT '], 116: [' M:OTHER ', ' M:PUNCT '], 117: [' M:PUNCT ', ' R:OTHER ', ' R:OTHER '], 118: [' R:OTHER ', ' M:PUNCT '], 119: [' U:NOUN:POSS ', ' R:OTHER ', ' M:PUNCT ', ' M:OTHER '], 120: [' M:PUNCT ', ' M:PUNCT '], 121: [' R:PREP ', ' U:PREP ', ' U:DET ', ' U:PUNCT ', ' R:NOUN ', ' R:OTHER ', ' R:NOUN ', ' R:VERB:TENSE '], 122: [' R:PRON ', ' R:VERB '], 123: [' U:OTHER '], 124: [' R:NOUN ', ' U:DET ', ...
# {8926: [3, 2, 0], 27287: [1], 10132: [8, 1], 8690: [1], 984: [1, 2, 0], 5713: [2], 2858: [14, 12, 6, 10, 28, 19, 0, 20, 22], 3227: [0, 1, 5, 2, 3], 654: [0, 1], 16425: [3, 5, 0], 11145: [1], 10580: [2, 1, 0], 4647: [10, 9, 4, 5, 1, 11, 16], 8666: [4, 2, 1, 0], 3233: [2, 1], 6619: [1], 4648: [3, 4, 0, 1], 8958: [2, 1], 2012: [5], 2210: [9, 5, 4], 33714: [0], 15811: [4, 11, 1], 2508: [2, 0], 4732: [2, 1, 0], 31049: [5, 3, 2, 0, 1], 13443: [3, 0, 1], 4974: [4, 2, 1], 6846: [1, 4], 19955: [0], 6621: [0], 33931: [6, 4, 3, 5], 4054: [6, 3, 1, 0], 3109: [1], 29661: [0], 6338: [1], 9325: [5], 2522: [1], 21099: [0], 16183: [2], 15902: [0], 30519: [3, 4, 2], 7411: [1], 25229: [0], 5538: [10, 1, 7, 8, 20, 3, 5], 31224: [1], 3808: [0], 11020: [0, 1], 614: [4, 0, 2, 5, 8], 22522: [1], 33282: [1, 0], 9904: [2], 3966: [1, 0, 3], 12717: [8, 3, 4], 6822: [2], 30808: [0], 20022: [1], 13403: [3, 2, 0], 23657: [1, 0], 26202: [3], 9552: [0], 22135: [9, 11, 6, 1, 4, 2], 936: [1], 26201: [1], 20414: [0], 7403: [3, 2], 29826: [3, 0], 9739: [0, 2, 1], 10445: [0], 9543: [20, 11, 21, 8, 9, 3, 7, 10, 0], 23275: [2, 3], 22375: [1, 0], 19722: [0], 6101: [5, 7, 6], 4127: [5, 8, 12, 1, 3, 6], 9813: [6, 0, 4, 5], 15403: [0, 1], 23242: [0], 7087: [0], 5081: [4, 22, 7, 24, 11, 5, 15, 0, 6], 13410: [1], 22349: [2, 0], 10374: [0], 537: [2], 14729: [3, 1], 23301: [6, 3, 0, 4], 3151: [6, 7, 1, 2], 8186: [2, 3], 28578: [0], 7704: [0, 1], 17521: [0, 1], 10003: [3, 2], 24180: [3], 13645: [0], 7705: [2, 3, 0], 416: [5], 3792: [0], 28106: [0], 21039: [0], 17642: [1, 0], 2335: [5, 1, 3], 17138: [2], 12362: [1], 5402: [0], 8094: [0], 24691: [0], 3564: [6, 4, 5, 7], 12220: [1, 0], 5226: [7, 6, 2, 1], 8563: [0, 3, 5, 1], 27527: [0], 5248: [3, 4, 6], 16461: [2], 2653: [2], 31292: [0], 10312: [1], 25557: [0], 16176: [3, 2], 14242: [2], 26605: [2], 19718: [1, 0], 28157: [0], 4170: [5, 0, 3, 4], 23388: [11, 5, 1], 29992: [1, 2], 11821: [3], 20465: [2, 3], 10332: [1, 18, 6, 0, 12, 14, 15, 2, 9], 6171: [4, 1], 3692: [2, 4, 3], 12232: [0], 24164: [0], 8106: [11], 6254: [1, 0], 6988: [5, 2, 0, 6, 3], 24727: [0], 3204: [1], 16170: [3], 20589: [0, 1], 22699: [3], 141: [2, 0, 1, 3], 21360: [1, 2], 3500: [0], 19521: [5, 2, 0, 7], 458: [4, 1, 0, 5], 16801: [0, 1], 22080: [3, 5, 0], 15298: [1], 19229: [0], 10681: [1], 31940: [1, 3], 25441: [0], 28510: [3, 5], 10061: [0, 3, 2], 9240: [1], 5530: [9, 0, 5, 7], 33056: [0], 13105: [1, 2], 5739: [3], 18128: [2, 4, 5, 1], 28275: [1, 0], 32690: [0, 1], 27194: [1], 11419: [0], 10658: [2], 7148: [4, 1, 2], 3091: [0, 1, 5], 7089: [1, 2], 23414: [2], 7147: [2, 1], 17418: [2], 17239: [0], 4986: [4], 6764: [5, 2, 4], 13918: [3], 10088: [1], 4105: [1, 3, 5], 4553: [1, 3], 695: [0], 6906: [0, 2], 18872: [1, 0, 2, 3], 33893: [0], 17793: [0], 15015: [0, 2], 6910: [0, 2, 5, 9, 10], 18932: [0], 9455: [6, 1], 8844: [0, 3, 4], 20067: [0], 17323: [1, 2], 9762: [4, 2, 3], 30972: [0], 18132: [1, 7, 3, 2, 5, 0], 26597: [2, 3], 16045: [1, 3], 18974: [1, 0], 24246: [1, 2], 20036: [0], 17427: [1, 3], 6135: [3, 2], 4649: [7, 2], 10297: [6, 2, 5, 7], 16933: [0, 2], 8687: [0, 4, 5, 2, 8, 11], 4104: [0], 2004: [1], 20437: [2, 5, 0, 1], 6323: [0], 13292: [3, 0], 20637: [1], 10157: [0, 1], 10278: [1, 0, 7], 4218: [3, 4], 10379: [18, 9, 5, 7, 13, 6, 1, 2, 3], 13134: [0, 1], 29439: [1, 2], 34093: [0], 29052: [0], 7138: [3], 17787: [1, 0], 31814: [0], 29438: [2, 0], 20653: [1], 20166: [0, 1], 5813: [1, 6, 2, 4], 5143: [0, 4, 1, 3], 23384: [0], 14663: [2, 0], 18608: [5, 3], 9609: [3], 19930: [3, 5], 8643: [4, 3, 5, 2], 17272: [1], 9179: [4, 9], 3900: [8], 7915: [9, 3], 1355: [3, 0], 24834: [13, 8, 12, 1, 2, 3, 7, 9, 10, 11], 8925: [13, 7, 0, 1, 3], 10076: [2, 0], 22453: [7, 14, 6, 0, 2, 11, 1], 10063: [1], 29315: [0], 14340: [1], 20769: [3, 0], 23244: [1], 17421: [1, 0, 6], 6688: [0], 12662: [3, 2], 30902: [0, 4], 4345: [2], 10491: [1], 5988: [1], 3350: [0, 3], 11397: [3, 0], 12385: [2, 0], 17363: [10, 3, 12, 7, 1, 2], 16695: [0], 7738: [0], 10054: [7, 1, 3, 6], 31083: [2], 1 ...
# {8926: [0, 2, 3], 27287: [1], 10132: [1, 8], 8690: [1], 984: [0, 1, 2], 5713: [2], 2858: [0, 6, 10, 12, 14, 19, 20, 22, 28], 3227: [0, 1, 2, 3, 5], 654: [0, 1], 16425: [0, 3, 5], 11145: [1], 10580: [0, 1, 2], 4647: [1, 4, 5, 9, 10, 11, 16], 8666: [0, 1, 2, 4], 3233: [1, 2], 6619: [1], 4648: [0, 1, 3, 4], 8958: [1, 2], 2012: [5], 2210: [4, 5, 9], 33714: [0], 15811: [1, 4, 11], 2508: [0, 2], 4732: [0, 1, 2], 31049: [0, 1, 2, 3, 5], 13443: [0, 1, 3], 4974: [1, 2, 4], 6846: [1, 4], 19955: [0], 6621: [0], 33931: [3, 4, 5, 6], 4054: [0, 1, 3, 6], 3109: [1], 29661: [0], 6338: [1], 9325: [5], 2522: [1], 21099: [0], 16183: [2], 15902: [0], 30519: [2, 3, 4], 7411: [1], 25229: [0], 5538: [1, 3, 5, 7, 8, 10, 20], 31224: [1], 3808: [0], 11020: [0, 1], 614: [0, 2, 4, 5, 8], 22522: [1], 33282: [0, 1], 9904: [2], 3966: [0, 1, 3], 12717: [3, 4, 8], 6822: [2], 30808: [0], 20022: [1], 13403: [0, 2, 3], 23657: [0, 1], 26202: [3], 9552: [0], 22135: [1, 2, 4, 6, 9, 11], 936: [1], 26201: [1], 20414: [0], 7403: [2, 3], 29826: [0, 3], 9739: [0, 1, 2], 10445: [0], 9543: [0, 3, 7, 8, 9, 10, 11, 20, 21], 23275: [2, 3], 22375: [0, 1], 19722: [0], 6101: [5, 6, 7], 4127: [1, 3, 5, 6, 8, 12], 9813: [0, 4, 5, 6], 15403: [0, 1], 23242: [0], 7087: [0], 5081: [0, 4, 5, 6, 7, 11, 15, 22, 24], 13410: [1], 22349: [0, 2], 10374: [0], 537: [2], 14729: [1, 3], 23301: [0, 3, 4, 6], 3151: [1, 2, 6, 7], 8186: [2, 3], 28578: [0], 7704: [0, 1], 17521: [0, 1], 10003: [2, 3], 24180: [3], 13645: [0], 7705: [0, 2, 3], 416: [5], 3792: [0], 28106: [0], 21039: [0], 17642: [0, 1], 2335: [1, 3, 5], 17138: [2], 12362: [1], 5402: [0], 8094: [0], 24691: [0], 3564: [4, 5, 6, 7], 12220: [0, 1], 5226: [1, 2, 6, 7], 8563: [0, 1, 3, 5], 27527: [0], 5248: [3, 4, 6], 16461: [2], 2653: [2], 31292: [0], 10312: [1], 25557: [0], 16176: [2, 3], 14242: [2], 26605: [2], 19718: [0, 1], 28157: [0], 4170: [0, 3, 4, 5], 23388: [1, 5, 11], 29992: [1, 2], 11821: [3], 20465: [2, 3], 10332: [0, 1, 2, 6, 9, 12, 14, 15, 18], 6171: [1, 4], 3692: [2, 3, 4], 12232: [0], 24164: [0], 8106: [11], 6254: [0, 1], 6988: [0, 2, 3, 5, 6], 24727: [0], 3204: [1], 16170: [3], 20589: [0, 1], 22699: [3], 141: [0, 1, 2, 3], 21360: [1, 2], 3500: [0], 19521: [0, 2, 5, 7], 458: [0, 1, 4, 5], 16801: [0, 1], 22080: [0, 3, 5], 15298: [1], 19229: [0], 10681: [1], 31940: [1, 3], 25441: [0], 28510: [3, 5], 10061: [0, 2, 3], 9240: [1], 5530: [0, 5, 7, 9], 33056: [0], 13105: [1, 2], 5739: [3], 18128: [1, 2, 4, 5], 28275: [0, 1], 32690: [0, 1], 27194: [1], 11419: [0], 10658: [2], 7148: [1, 2, 4], 3091: [0, 1, 5], 7089: [1, 2], 23414: [2], 7147: [1, 2], 17418: [2], 17239: [0], 4986: [4], 6764: [2, 4, 5], 13918: [3], 10088: [1], 4105: [1, 3, 5], 4553: [1, 3], 695: [0], 6906: [0, 2], 18872: [0, 1, 2, 3], 33893: [0], 17793: [0], 15015: [0, 2], 6910: [0, 2, 5, 9, 10], 18932: [0], 9455: [1, 6], 8844: [0, 3, 4], 20067: [0], 17323: [1, 2], 9762: [2, 3, 4], 30972: [0], 18132: [0, 1, 2, 3, 5, 7], 26597: [2, 3], 16045: [1, 3], 18974: [0, 1], 24246: [1, 2], 20036: [0], 17427: [1, 3], 6135: [2, 3], 4649: [2, 7], 10297: [2, 5, 6, 7], 16933: [0, 2], 8687: [0, 2, 4, 5, 8, 11], 4104: [0], 2004: [1], 20437: [0, 1, 2, 5], 6323: [0], 13292: [0, 3], 20637: [1], 10157: [0, 1], 10278: [0, 1, 7], 4218: [3, 4], 10379: [1, 2, 3, 5, 6, 7, 9, 13, 18], 13134: [0, 1], 29439: [1, 2], 34093: [0], 29052: [0], 7138: [3], 17787: [0, 1], 31814: [0], 29438: [0, 2], 20653: [1], 20166: [0, 1], 5813: [1, 2, 4, 6], 5143: [0, 1, 3, 4], 23384: [0], 14663: [0, 2], 18608: [3, 5], 9609: [3], 19930: [3, 5], 8643: [2, 3, 4, 5], 17272: [1], 9179: [4, 9], 3900: [8], 7915: [3, 9], 1355: [0, 3], 24834: [1, 2, 3, 7, 8, 9, 10, 11, 12, 13], 8925: [0, 1, 3, 7, 13], 10076: [0, 2], 22453: [0, 1, 2, 6, 7, 11, 14], 10063: [1], 29315: [0], 14340: [1], 20769: [0, 3], 23244: [1], 17421: [0, 1, 6], 6688: [0], 12662: [2, 3], 30902: [0, 4], 4345: [2], 10491: [1], 5988: [1], 3350: [0, 3], 11397: [0, 3], 12385: [0, 2], 17363: [1, 2, 3, 7, 10, 12], 16695: [0], 7738: [0], 10054: [1, 3, 6, 7], 31083: [2], 1 ...

# %%
idx_error_ann_idx
# Out:
# {8926: [0, 2, 3],
#  27287: [1],
#  10132: [1, 8],
#  8690: [1],
#  984: [0, 1, 2],
#  5713: [2],
#  2858: [0, 6, 10, 12, 14, 19, 20, 22, 28],
#  3227: [0, 1, 2, 3, 5],
#  654: [0, 1],
#  16425: [0, 3, 5],
#  11145: [1],
#  10580: [0, 1, 2],
#  4647: [1, 4, 5, 9, 10, 11, 16],
#  8666: [0, 1, 2, 4],
#  3233: [1, 2],
#  6619: [1],
#  4648: [0, 1, 3, 4],
#  8958: [1, 2],
#  2012: [5],
#  2210: [4, 5, 9],
#  33714: [0],
#  15811: [1, 4, 11],
#  2508: [0, 2],
#  4732: [0, 1, 2],
#  31049: [0, 1, 2, 3, 5],
#  13443: [0, 1, 3],
#  4974: [1, 2, 4],
#  6846: [1, 4],
#  19955: [0],
#  6621: [0],
#  33931: [3, 4, 5, 6],
#  4054: [0, 1, 3, 6],
#  3109: [1],
#  29661: [0],
#  6338: [1],
#  9325: [5],
#  2522: [1],
#  21099: [0],
#  16183: [2],
#  15902: [0],
#  30519: [2, 3, 4],
#  7411: [1],
#  25229: [0],
#  5538: [1, 3, 5, 7, 8, 10, 20],
#  31224: [1],
#  3808: [0],
#  11020: [0, 1],
#  614: [0, 2, 4, 5, 8],
#  22522: [1],
#  33282: [0, 1],
#  9904: [2],
#  3966: [0, 1, 3],
#  12717: [3, 4, 8],
#  6822: [2],
#  30808: [0],
#  20022: [1],
#  13403: [0, 2, 3],
#  23657: [0, 1],
#  26202: [3],
#  9552: [0],
#  22135: [1, 2, 4, 6, 9, 11],
#  936: [1],
#  26201: [1],
#  20414: [0],
#  7403: [2, 3],
#  29826: [0, 3],
#  9739: [0, 1, 2],
#  10445: [0],
#  9543: [0, 3, 7, 8, 9, 10, 11, 20, 21],
#  23275: [2, 3],
#  22375: [0, 1],
#  19722: [0],
#  6101: [5, 6, 7],
#  4127: [1, 3, 5, 6, 8, 12],
#  9813: [0, 4, 5, 6],
#  15403: [0, 1],
#  23242: [0],
#  7087: [0],
#  5081: [0, 4, 5, 6, 7, 11, 15, 22, 24],
#  13410: [1],
#  22349: [0, 2],
#  10374: [0],
#  537: [2],
#  14729: [1, 3],
#  23301: [0, 3, 4, 6],
#  3151: [1, 2, 6, 7],
#  8186: [2, 3],
#  28578: [0],
#  7704: [0, 1],
#  17521: [0, 1],
#  10003: [2, 3],
#  24180: [3],
#  13645: [0],
#  7705: [0, 2, 3],
#  416: [5],
#  3792: [0],
#  28106: [0],
#  21039: [0],
#  17642: [0, 1],
#  2335: [1, 3, 5],
#  17138: [2],
#  12362: [1],
#  5402: [0],
#  8094: [0],
#  24691: [0],
#  3564: [4, 5, 6, 7],
#  12220: [0, 1],
#  5226: [1, 2, 6, 7],
#  8563: [0, 1, 3, 5],
#  27527: [0],
#  5248: [3, 4, 6],
#  16461: [2],
#  2653: [2],
#  31292: [0],
#  10312: [1],
#  25557: [0],
#  16176: [2, 3],
#  14242: [2],
#  26605: [2],
#  19718: [0, 1],
#  28157: [0],
#  4170: [0, 3, 4, 5],
#  23388: [1, 5, 11],
#  29992: [1, 2],
#  11821: [3],
#  20465: [2, 3],
#  10332: [0, 1, 2, 6, 9, 12, 14, 15, 18],
#  6171: [1, 4],
#  3692: [2, 3, 4],
#  12232: [0],
#  24164: [0],
#  8106: [11],
#  6254: [0, 1],
#  6988: [0, 2, 3, 5, 6],
#  24727: [0],
#  3204: [1],
#  16170: [3],
#  20589: [0, 1],
#  22699: [3],
#  141: [0, 1, 2, 3],
#  21360: [1, 2],
#  3500: [0],
#  19521: [0, 2, 5, 7],
#  458: [0, 1, 4, 5],
#  16801: [0, 1],
#  22080: [0, 3, 5],
#  15298: [1],
#  19229: [0],
#  10681: [1],
#  31940: [1, 3],
#  25441: [0],
#  28510: [3, 5],
#  10061: [0, 2, 3],
#  9240: [1],
#  5530: [0, 5, 7, 9],
#  33056: [0],
#  13105: [1, 2],
#  5739: [3],
#  18128: [1, 2, 4, 5],
#  28275: [0, 1],
#  32690: [0, 1],
#  27194: [1],
#  11419: [0],
#  10658: [2],
#  7148: [1, 2, 4],
#  3091: [0, 1, 5],
#  7089: [1, 2],
#  23414: [2],
#  7147: [1, 2],
#  17418: [2],
#  17239: [0],
#  4986: [4],
#  6764: [2, 4, 5],
#  13918: [3],
#  10088: [1],
#  4105: [1, 3, 5],
#  4553: [1, 3],
#  695: [0],
#  6906: [0, 2],
#  18872: [0, 1, 2, 3],
#  33893: [0],
#  17793: [0],
#  15015: [0, 2],
#  6910: [0, 2, 5, 9, 10],
#  18932: [0],
#  9455: [1, 6],
#  8844: [0, 3, 4],
#  20067: [0],
#  17323: [1, 2],
#  9762: [2, 3, 4],
#  30972: [0],
#  18132: [0, 1, 2, 3, 5, 7],
#  26597: [2, 3],
#  16045: [1, 3],
#  18974: [0, 1],
#  24246: [1, 2],
#  20036: [0],
#  17427: [1, 3],
#  6135: [2, 3],
#  4649: [2, 7],
#  10297: [2, 5, 6, 7],
#  16933: [0, 2],
#  8687: [0, 2, 4, 5, 8, 11],
#  4104: [0],
#  2004: [1],
#  20437: [0, 1, 2, 5],
#  6323: [0],
#  13292: [0, 3],
#  20637: [1],
#  10157: [0, 1],
#  10278: [0, 1, 7],
#  4218: [3, 4],
#  10379: [1, 2, 3, 5, 6, 7, 9, 13, 18],
#  13134: [0, 1],
#  29439: [1, 2],
#  34093: [0],
#  29052: [0],
#  7138: [3],
#  17787: [0, 1],
#  31814: [0],
#  29438: [0, 2],
#  20653: [1],
#  20166: [0, 1],
#  5813: [1, 2, 4, 6],
#  5143: [0, 1, 3, 4],
#  23384: [0],
#  14663: [0, 2],
#  18608: [3, 5],
#  9609: [3],
#  19930: [3, 5],
#  8643: [2, 3, 4, 5],
#  17272: [1],
#  9179: [4, 9],
#  3900: [8],
#  7915: [3, 9],
#  1355: [0, 3],
#  24834: [1, 2, 3, 7, 8, 9, 10, 11, 12, 13],
#  8925: [0, 1, 3, 7, 13],
#  10076: [0, 2],
#  22453: [0, 1, 2, 6, 7, 11, 14],
#  10063: [1],
#  29315: [0],
#  14340: [1],
#  20769: [0, 3],
#  23244: [1],
#  17421: [0, 1, 6],
#  6688: [0],
#  12662: [2, 3],
#  30902: [0, 4],
#  4345: [2],
#  10491: [1],
#  5988: [1],
#  3350: [0, 3],
#  11397: [0, 3],
#  12385: [0, 2],
#  17363: [1, 2, 3, 7, 10, 12],
#  16695: [0],
#  7738: [0],
#  10054: [1, 3, 6, 7],
#  31083: [2],
#  12517: [1],
#  10908: [0, 1, 3, 4, 5, 8, 9, 12, 13, 14, 19],
#  23030: [1],
#  22429: [4, 5],
#  13287: [0, 2, 4, 7],
#  4217: [1, 2, 4],
#  1129: [4, 5, 9, 16, 18, 21],
#  8868: [2],
#  5413: [0],
#  13494: [0, 3, 4],
#  296: [0],
#  25254: [0, 1, 2],
#  20121: [2],
#  17811: [0],
#  23562: [0, 1, 2],
#  945: [3],
#  19194: [1],
#  17430: [0, 2],
#  14439: [2, 3, 6],
#  15021: [0, 3, 7],
#  1389: [0, 2],
#  17573: [1],
#  24133: [1, 2, 3],
#  15095: [0],
#  21394: [3, 4],
#  21113: [0],
#  6185: [0, 1],
#  19167: [1],
#  3683: [1],
#  4026: [1, 2, 5, 6],
#  30693: [1],
#  7569: [0],
#  7798: [0, 3, 4, 7],
#  7954: [1, 2, 4],
#  27849: [0, 1],
#  15073: [1],
#  28694: [1],
#  13894: [0, 1],
#  1618: [0, 1, 2],
#  9149: [2, 3],
#  8616: [0, 1, 2],
#  33546: [1],
#  14440: [0],
#  21761: [0, 1, 5, 14, 19, 24, 31],
#  7136: [1],
#  4918: [1, 2, 4],
#  14305: [0, 3],
#  13885: [0, 2],
#  4417: [2, 5],
#  17289: [0, 2],
#  1536: [2],
#  9767: [0, 1, 3, 4, 6, 8, 11],
#  3492: [2],
#  14147: [1, 3],
#  20890: [2],
#  10068: [1, 3, 4],
#  32258: [0],
#  13749: [1, 2],
#  32315: [0, 1],
#  20422: [1, 5, 7],
#  4776: [3, 5],
#  22460: [3],
#  24850: [2],
#  6174: [0, 2],
#  23276: [0, 2],
#  31533: [0, 1, 2],
#  7377: [0],
#  21563: [1, 3, 5, 11],
#  8762: [1, 3, 4],
#  1345: [0, 4],
#  20286: [0],
#  16577: [1],
#  16804: [0, 1],
#  6767: [0, 8, 11],
#  14183: [1, 3, 4],
#  29775: [0, 1],
#  2248: [5],
#  8645: [0, 4],
#  3547: [0, 3, 4],
#  34274: [0, 2],
#  9312: [0, 2],
#  1177: [0, 1, 2],
#  8571: [1, 2, 3, 6, 7],
#  25619: [0],
#  16276: [2, 5],
#  25452: [1, 2, 3],
#  9076: [4, 7],
#  8107: [1, 5, 7, 14],
#  30897: [0, 1],
#  1580: [0, 1, 5, 8],
#  29384: [0],
#  5731: [2],
#  33055: [0],
#  5318: [0, 3, 4, 5],
#  24033: [0],
#  8272: [2],
#  30057: [1],
#  5663: [1, 4],
#  9783: [0],
#  2469: [0, 5],
#  10564: [0, 1],
#  3127: [1, 5],
#  14614: [1, 4],
#  811: [1],
#  7502: [4, 6],
#  24523: [4],
#  8842: [0, 1, 4],
#  22092: [1],
#  29953: [0, 2, 3],
#  27282: [4],
#  5058: [0, 3],
#  7423: [0],
#  21367: [1, 3],
#  6913: [0],
#  6576: [5, 7],
#  25124: [0],
#  21923: [0, 2, 3, 4, 6, 7],
#  10563: [4, 5],
#  33152: [0],
#  13311: [0, 1],
#  956: [0, 5],
#  19004: [0, 6, 7],
#  31355: [0],
#  22811: [0, 3],
#  22993: [0, 1, 2],
#  6651: [5, 8, 10, 13, 15, 16, 17],
#  14758: [0, 1],
#  2865: [2],
#  18129: [1, 3, 5, 6],
#  7142: [3],
#  16816: [2],
#  11216: [0],
#  5747: [1, 4],
#  5662: [3, 4, 7],
#  19740: [2],
#  3818: [3, 4, 6],
#  25375: [3],
#  29497: [0, 4],
#  8766: [0, 2],
#  9446: [1, 4, 5, 6],
#  2417: [0],
#  968: [2, 4],
#  22765: [0, 1, 2, 3],
#  32640: [0],
#  10872: [0],
#  16476: [2, 3],
#  27985: [0],
#  29089: [0],
#  11120: [1],
#  20741: [0],
#  21734: [0, 1],
#  5528: [2, 3],
#  8417: [1],
#  5707: [1, 3, 5],
#  14564: [0, 2, 4],
#  9627: [0, 3, 5],
#  3557: [1, 3],
#  16103: [2],
#  6967: [2],
#  21849: [0],
#  667: [0],
#  9980: [0, 1],
#  12724: [0, 3, 5],
#  24152: [0, 1, 3],
#  23430: [0, 1],
#  17346: [2],
#  2735: [0, 1, 3, 4, 7, 10, 12, 16, 17],
#  8617: [1],
#  31937: [1],
#  28404: [1],
#  13432: [0, 2],
#  26728: [2],
#  6754: [1, 6, 7, 8],
#  33194: [0],
#  253: [0, 2],
#  31808: [0],
#  4774: [1],
#  3937: [1],
#  2977: [3],
#  29950: [0],
#  12369: [0],
#  20670: [1, 2],
#  732: [1, 4],
#  14487: [3, 4, 5],
#  19697: [0],
#  1224: [6],
#  23936: [0],
#  17485: [0],
#  7259: [0, 1],
#  5826: [0],
#  5541: [0, 2, 4],
#  32873: [2, 3],
#  14043: [1],
#  4305: [1, 2],
#  19608: [0],
#  12022: [2],
#  10826: [0],
#  14651: [0, 2, 3, 4],
#  6099: [0],
#  29429: [2],
#  16733: [1],
#  10215: [0],
#  22246: [2],
#  12341: [2, 4],
#  4983: [1, 2],
#  15366: [0],
#  23428: [0],
#  9617: [0, 1, 7],
#  20667: [3, 4],
#  6164: [1, 5, 7],
#  16162: [3, 4],
#  17897: [0, 2],
#  21161: [0],
#  23346: [0, 2],
#  5378: [0, 2],
#  12179: [0, 1],
#  33919: [0],
#  33914: [0],
#  1480: [0, 1],
#  29131: [1],
#  2856: [0, 2],
#  18238: [2],
#  11300: [0],
#  20200: [3, 5],
#  18422: [0],
#  20867: [0, 1],
#  15509: [0],
#  8569: [0, 1],
#  22547: [1],
#  31480: [1, 3, 4],
#  5847: [0, 1, 3, 5, 6, 7, 11, 14, 17],
#  24637: [0, 1, 5, 8],
#  3844: [2],
#  4855: [2],
#  11849: [0, 1],
#  6914: [2, 3],
#  11170: [0],
#  13513: [1],
#  30522: [0],
#  23252: [0],
#  13335: [0, 2, 3],
#  26609: [0],
#  3039: [0],
#  7787: [0, 2, 3, 4, 5, 8, 10, 13],
#  32473: [0],
#  18257: [0, 1, 2],
#  13807: [1],
#  34161: [1, 2],
#  20493: [2, 8, 9, 10],
#  27549: [1],
#  27148: [1, 2],
#  10381: [1, 2],
#  23261: [0],
#  9480: [0],
#  16731: [3],
#  31949: [0, 1, 2, 5, 6],
#  2107: [0, 3, 4, 5, 7, 8, 9],
#  27149: [1],
#  3390: [1, 2],
#  9257: [1, 2],
#  25463: [2],
#  22854: [0],
#  17945: [1],
#  7002: [0],
#  3159: [0],
#  26199: [0, 1],
#  20358: [0],
#  30158: [0],
#  17288: [0, 1],
#  8408: [0, 5],
#  31189: [0],
#  33089: [0, 1],
#  18000: [0, 1],
#  7014: [2],
#  27341: [3],
#  33099: [1, 2],
#  11339: [1, 4, 8, 16],
#  7637: [1],
#  6698: [2, 3],
#  28660: [0, 4],
#  20064: [0, 2, 3],
#  9510: [0, 2],
#  28491: [0, 1, 2, 3],
#  358: [1, 4],
#  3433: [1, 3, 4],
#  10382: [1, 3, 4],
#  7167: [2, 3],
#  22846: [0, 2, 6],
#  31649: [0],
#  24626: [0, 1],
#  23705: [1],
#  2082: [0],
#  30804: [0],
#  9136: [0],
#  9131: [0],
#  21869: [0],
#  14571: [0, 1],
#  19020: [1],
#  15122: [0, 1, 6],
#  9437: [0, 3],
#  14570: [0, 1, 2, 3],
#  9254: [0],
#  30809: [1],
#  7246: [0],
#  14545: [1],
#  17689: [1],
#  27689: [0, 1],
#  3959: [1],
#  33534: [0],
#  18010: [0],
#  23262: [1],
#  9052: [1, 4, 5],
#  18007: [1],
#  16175: [1, 2],
#  13856: [2],
#  22797: [1],
#  2962: [0],
#  30326: [0, 1],
#  23908: [0],
#  28126: [0, 1],
#  17718: [0],
#  21725: [0],
#  4879: [1, 2],
#  2399: [0, 1, 2, 4, 8, 9, 13, 16],
#  13352: [0],
#  12378: [0, 2, 4, 6],
#  4515: [1],
#  625: [0, 1],
#  7179: [0],
#  28617: [0],
#  3126: [1, 3, 9],
#  14417: [0],
#  6423: [0, 4],
#  13035: [0],
#  24603: [1],
#  20214: [0],
#  34267: [0, 1],
#  13195: [1],
#  6711: [0, 3, 4],
#  13359: [2],
#  21963: [0, 1],
#  24084: [2],
#  14081: [0],
#  28391: [0, 1],
#  26560: [0],
#  970: [3],
#  26441: [0],
#  4852: [1, 3],
#  11360: [0, 1],
#  25184: [0],
#  27144: [0, 1],
#  33900: [0],
#  33766: [1],
#  24905: [1],
#  21630: [2],
#  15179: [0],
#  18353: [0, 3, 4, 9],
#  25917: [0],
#  27044: [0],
#  31445: [0],
#  3997: [0, 2, 3, 4, 6],
#  3843: [2, 3],
#  29034: [0, 1],
#  24751: [0],
#  17002: [1, 2, 3, 5],
#  10369: [1, 6],
#  25035: [0],
#  26815: [2],
#  25916: [2],
#  6696: [2, 3, 5],
#  14992: [1],
#  762: [1],
#  14476: [1],
#  30728: [1],
#  4107: [2, 3],
#  6268: [1, 2, 3, 4, 5, 6, 7],
#  19859: [0],
#  7261: [1, 2, 3],
#  9532: [1, 4, 6, 8, 9, 10, 16, 17, 24],
#  9363: [0, 2, 3],
#  8472: [1, 2, 4, 5, 6, 7, 8, 11, 15, 18, 20, 21, 22, 27],
#  1169: [8],
#  33834: [1, 2, 3],
#  256: [5, 15, 17, 21, 31],
#  22180: [0, 1, 3, 4],
#  14050: [0, 1, 2],
#  4039: [0],
#  22124: [0],
#  364: [1],
#  10110: [0],
#  15447: [0],
#  14887: [1],
#  22294: [0],
#  16006: [1],
#  15100: [0, 2, 4],
#  1165: [1, 2, 3],
#  10218: [0, 3],
#  11373: [1],
#  11983: [0, 1, 5, 8],
#  30243: [0],
#  7405: [0, 5, 6, 9],
#  27976: [3],
#  11883: [1],
#  1556: [0],
#  5207: [3, 4],
#  8898: [2, 4, 6],
#  8266: [0, 2],
#  21141: [1, 6, 7],
#  2981: [4, 16],
#  1516: [0, 6, 8, 9],
#  1306: [0],
#  15463: [1, 2],
#  13028: [0],
#  9432: [0, 4],
#  14406: [2],
#  11835: [1, 2],
#  3946: [2, 5, 8, 9, 10, 12],
#  19067: [0, 2],
#  30239: [0],
#  18501: [0, 1],
#  16107: [1],
#  25974: [1],
#  28548: [0],
#  12722: [0],
#  9495: [0, 1],
#  171: [1, 3, 5],
#  6404: [4],
#  4228: [0, 1, 2, 3, 5, 10, 12, 16, 23, 31],
#  28185: [1, 2],
#  1807: [1, 2],
#  5447: [0, 1, 3, 4, 5, 7, 8, 11],
#  31619: [1, 3],
#  11549: [2],
#  14148: [0],
#  30781: [0, 1],
#  946: [0, 1, 3, 9, 10, 12, 17],
#  886: [0, 1, 2],
#  34176: [0, 1, 2, 4],
#  2246: [4],
#  23287: [1],
#  22486: [0, 1],
#  13158: [2],
#  3728: [0],
#  21405: [3],
#  15693: [0],
#  12409: [0, 3],
#  150: [2],
#  33309: [1],
#  16054: [1],
#  18362: [0, 1, 2],
#  15050: [0, 3],
#  11647: [0],
#  29730: [3],
#  11781: [0, 1, 2, 3, 5, 7],
#  8315: [0],
#  12433: [0, 1],
#  10697: [4],
#  30275: [1],
#  4233: [0],
#  14260: [1, 2, 6, 8],
#  7889: [0, 1],
#  529: [1],
#  10721: [0, 4],
#  13198: [0],
#  17559: [0],
#  14814: [0, 1],
#  16268: [0],
#  19375: [0, 3, 4],
#  12342: [4],
#  16699: [0, 1],
#  31751: [1],
#  31658: [1],
#  3343: [0],
#  23002: [1],
#  8470: [4],
#  12998: [0, 1],
#  92: [1],
#  22402: [3],
#  10281: [0, 3, 8],
#  14375: [0],
#  24788: [1, 3],
#  9940: [0],
#  18552: [2, 5, 7, 8],
#  18593: [2],
#  32685: [0, 3],
#  14071: [2],
#  20922: [0, 1, 4],
#  4030: [0],
#  10116: [0, 1],
#  23978: [0, 1, 2],
#  4731: [0],
#  17563: [0],
#  10386: [0, 2, 8],
#  2609: [0],
#  4074: [0, 3, 6, 8],
#  17477: [0, 4],
#  135: [0, 1, 8],
#  9592: [1],
#  3995: [0],
#  23481: [0, 1, 3],
#  10121: [1, 2, 6],
#  21593: [0, 1],
#  11850: [0, 1, 3],
#  22573: [1],
#  19586: [1],
#  20482: [1],
#  1878: [0],
#  26769: [1, 2, 3],
#  30300: [1, 2, 4],
#  23425: [0, 2, 3],
#  24874: [1],
#  10186: [0, 1, 4, 7, 9],
#  14511: [1, 4],
#  3574: [2, 4, 5, 9, 10],
#  12066: [1],
#  9697: [0, 1, 3, 7, 8, 10],
#  1152: [1, 2, 8, 10],
#  18182: [0],
#  25826: [0, 1],
#  17864: [3],
#  15119: [1, 2, 3, 4, 5],
#  18155: [0, 2, 3],
#  13821: [1, 2],
#  17428: [5],
#  4012: [3, 4],
#  8120: [1],
#  9621: [1, 2],
#  20151: [0],
#  910: [4, 5, 8],
#  2617: [0, 1, 2, 3],
#  2619: [0],
#  1390: [1, 2, 3],
#  5214: [0, 3, 4, 5],
#  16800: [0, 1, 3],
#  9987: [1],
#  8663: [6, 10, 15, 17],
#  2987: [4, 5, 7],
#  22209: [0, 2],
#  5993: [1],
#  823: [0],
#  15461: [1],
#  22806: [3],
#  1637: [4, 7],
#  22388: [0],
#  24995: [1, 3],
#  19106: [1],
#  18870: [4, 6],
#  7995: [0],
#  24635: [0],
#  26478: [2],
#  5963: [1, 2, 5],
#  362: [1, 3, 4, 7],
#  3098: [1, 2],
#  12686: [0, 1],
#  22131: [0, 2],
#  24462: [1],
#  3967: [0, 1, 3],
#  12403: [1],
#  32135: [1],
#  16932: [0, 1, 2],
#  9234: [0, 2],
#  2545: [2, 5, 6],
#  31491: [1],
#  21908: [0, 2],
#  22126: [2],
#  20492: [0],
#  23202: [0],
#  133: [6, 7],
#  9500: [0],
#  5096: [0, 2, 3],
#  13655: [1],
#  7655: [2, 3],
#  1957: [0, 1, 2, 4, 6, 8, 9, 10, 11, 12, 14, 32, 40],
#  6876: [3],
#  8195: [0],
#  10667: [2],
#  11150: [0],
#  1360: [1, 2],
#  3460: [0, 2],
#  3552: [0, 1, 7],
#  16163: [1],
#  9846: [2, 4],
#  2784: [0],
#  3383: [1],
#  907: [1, 6, 7, 10, 11, 12],
#  6257: [0, 2],
#  29218: [1],
#  2668: [0],
#  7112: [5, 6],
#  8570: [0, 2, 3],
#  1310: [0],
#  34058: [1],
#  1966: [0],
#  4043: [0, 2],
#  5215: [1, 6, 10, 11, 17],
#  24576: [1],
#  18819: [6],
#  9898: [5, 7],
#  9061: [0, 1, 2, 5, 6],
#  8111: [0],
#  28205: [0, 1],
#  1314: [0, 2, 3],
#  22620: [2],
#  8153: [0, 1, 3, 4],
#  21833: [1],
#  4080: [4, 5, 10],
#  9703: [5, 10, 12],
#  3045: [1],
#  2298: [0, 1],
#  1405: [1, 2, 3],
#  19385: [2, 3],
#  13984: [3, 4],
#  4518: [1, 2],
#  18221: [0, 3],
#  4886: [0,
#   1,
#   3,
#   4,
#   5,
#   6,
#   8,
#   9,
#   13,
#   15,
#   16,
#   19,
#   20,
#   21,
#   23,
#   26,
#   28,
#   32,
#   33,
#   36,
#   38,
#   42],
#  16572: [0],
#  23970: [2],
#  27255: [0, 1],
#  22539: [0, 1],
#  29317: [1],
#  14196: [6, 8],
#  4339: [1, 3],
#  323: [0],
#  25750: [0],
#  8685: [2, 3, 4, 6],
#  5499: [4],
#  26210: [4],
#  23962: [1],
#  6330: [2],
#  297: [0, 5, 9, 10, 14],
#  29046: [2],
#  10686: [1, 3],
#  10198: [1],
#  22484: [2, 3],
#  6219: [1, 3, 6],
#  32988: [0],
#  1990: [5],
#  29873: [0, 3],
#  6182: [0, 1],
#  25403: [0, 1, 2],
#  9408: [0, 1],
#  3133: [1, 5],
#  3939: [5],
#  8769: [0, 1],
#  23029: [1],
#  23302: [1],
#  5840: [0, 2],
#  33286: [1],
#  12825: [0],
#  4467: [0, 1, 2, 3, 5],
#  3545: [0, 1, 2, 4],
#  11541: [2],
#  16125: [0, 1],
#  9808: [0],
#  11031: [0],
#  10701: [0],
#  14455: [0, 3],
#  12559: [2],
#  20397: [1, 5],
#  5264: [0, 2, 3],
#  29909: [1],
#  14156: [0, 1, 4],
#  7948: [0, 1],
#  174: [0],
#  8706: [0],
#  4115: [0],
#  17892: [1],
#  14699: [0, 3],
#  11474: [0],
#  10005: [2, 3],
#  10985: [1, 4],
#  3394: [0, 1],
#  11863: [0],
#  25924: [1, 2, 3],
#  6730: [2, 4, 7, 12],
#  7983: [0, 4],
#  4766: [1],
#  6742: [0, 2, 3, 5],
#  13561: [0],
#  11858: [0, 1],
#  16282: [1],
#  22999: [1],
#  12316: [0],
#  7130: [0],
#  16726: [1],
#  9896: [4],
#  7338: [1],
#  3191: [0, 1],
#  20452: [0, 3, 4],
#  2765: [0, 6],
#  219: [0, 3, 4, 5, 7, 10, 13, 15, 16, 18, 20],
#  34221: [0],
#  23187: [3, 5],
#  15094: [0, 1],
#  5667: [0, 1],
#  21457: [0, 2],
#  11381: [1, 5, 6, 7, 11],
#  11045: [0, 2, 4, 6],
#  5036: [1, 3],
#  4554: [0],
#  18050: [1],
#  15344: [0, 1, 2],
#  8818: [0, 1],
#  2796: [0],
#  1680: [1],
#  4718: [2],
#  8816: [1],
#  5456: [7, 8],
#  1529: [0, 1, 2],
#  21037: [0],
#  22321: [2, 3],
#  30069: [0],
#  3779: [2, 4, 5, 8, 10],
#  8838: [0],
#  1612: [0],
#  16197: [0],
#  2926: [0],
#  10699: [2],
#  15564: [0, 4],
#  9066: [1, 2],
#  2636: [5, 6],
#  18990: [0, 3],
#  11836: [2],
#  4614: [4, 5],
#  1623: [2, 4],
#  26788: [0, 1, 6],
#  23448: [0, 1],
#  3025: [2],
#  5942: [0, 1],
#  5742: [0, 2, 3],
#  1826: [0],
#  8273: [2, 3, 6, 10],
#  19513: [1],
#  1588: [3],
#  1627: [2, 4, 5],
#  29924: [4, 6],
#  91: [0],
#  20215: [1],
#  14138: [0, 2],
#  16957: [0],
#  ...}

# %%
errors_by_sentence[18649]
# Out:
# ['M:DET']

# %%
annotations[3]
# Out:
# ['A 8 9 ||| R:SPELL ||| center ||| REQUIRED ||| -NONE- ||| 0\n']

# %%
def get_errors_to_suppress(goal_error_dist_count, errors_by_sentence): 
  errors_to_suppress = {} 
  for sent_idx in errors_by_sentence.keys(): 
    annot_idx = 0
    errors_to_suppress[sent_idx] = []
    missing_suppressed = False # has at least one MISSING error been suppressed? 
    for error in errors_by_sentence[sent_idx]:
      goal_error_dist_count[error] -= 1 
      # TODO: check if this logic is okay  
      if goal_error_dist_count[error] <= 0: 
        if error[0] == 'M': 
          if not missing_suppressed: 
            errors_to_suppress[sent_idx].append(annot_idx)
            missing_suppressed = True 
        else: 
          errors_to_suppress[sent_idx].append(annot_idx)


      annot_idx += 1
    
  return errors_to_suppress

# %%
errors_to_suppress = get_errors_to_suppress(goal_error_dist_count, errors_by_sentence)

print(errors_to_suppress)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-f4d691f9a6c1> in <module>
# ----> 1 errors_to_suppress = get_errors_to_suppress(goal_error_dist_count, errors_by_sentence)
#       2
#       3 print(errors_to_suppress)
#
# <ipython-input-27-06175c55d5a5> in get_errors_to_suppress(goal_error_dist_count, errors_by_sentence)
#       6     missing_suppressed = False # has at least one MISSING error been suppressed?
#       7     for error in errors_by_sentence[sent_idx]:
# ----> 8       goal_error_dist_count[error] -= 1
#       9       # TODO: check if this logic is okay
#      10       if goal_error_dist_count[error] <= 0:
#
# KeyError: 'M:CONTR'

# %% [markdown]
# ## Part 2: Fix the errors in the file

# %% [markdown]
# Types of errors:
# - R: Replace
# - M: Missing
# - U: Unnecessary
# - noop

# %%
def supresser_method(sentence_dict):

    # idx_change is used to adjust the indices of the edits
    idx_change = 0
    # sentence_list is the source/S sentence in a list format
    sentence_list = sentence_dict['S'].split(' ')

    # iterating over the annotations
    for x in sentence_dict['A']:
        # getting the type edit
        type_edit = x[1].split(':')[0]

        # getting the start index from the annotation line and adjusting for subsequent changes
        str_idx = int(x[0].split(' ')[1])
        str_idx = str_idx + idx_change

        # getting the end index from the annotation line and adjusting for subsequent changes
        end_idx = int(x[0].split(' ')[2])
        end_idx = end_idx + idx_change

        # calculating the count of elements to be inserted
        if len(x[2]) > 0:
            insert_count = int(len(x[2].split(' ')))
            insert_str_list = x[2].split(' ')
        else:
            insert_count = 0

        # code for deleting elements and updating the idx change
        if str_idx == end_idx:
            pass
        else:
            del sentence_list[str_idx:end_idx]
            idx_change = idx_change - (end_idx - str_idx)

        # code for inserting elements and updating the idx change
        if insert_count == 0:
            pass
        else:
            sentence_list[str_idx:str_idx] = insert_str_list
            idx_change = idx_change + len(insert_str_list)

    return sentence_list

# %%
sentences[3]
# Out:
# 'I recommend visiting the artificial lake in the certer of the city which is surrounded by a park .'

# %%
annotations[3]
# Out:
# ['A 8 9 ||| R:SPELL ||| center ||| REQUIRED ||| -NONE- ||| 0\n']

# %%
sentence_dict = {}
sentence_dict['S'] = sentences[3]#'Firstly , I would like to tell you , that the group has been booked into Palace Hotel , which locates beside the congress house in the centre .'
sentence_dict['A'] = []
selected_annotations = []
##
for x in annotations[3]:  
  sentence_dict['A'].append(x.split('|||'))

output_list = supresser_method(sentence_dict)
print(*output_list)
# Out:
# I recommend visiting the artificial lake in the  center  of the city which is surrounded by a park .

# %%
idx = 3427
annoations_to_suppress = []
for x in idx_error_ann_idx[idx]:
  print(annotations[idx][x])
  annoations_to_suppress.append(annotations[idx][x].split('|||'))
print(annoations_to_suppress)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-1d009dafa422> in <module>
#       1 idx = 3427
#       2 annoations_to_suppress = []
# ----> 3 for x in idx_error_ann_idx[idx]:
#       4   print(annotations[idx][x])
#       5   annoations_to_suppress.append(annotations[idx][x].split('|||'))
#
# KeyError: 3427

# %%
annoations_to_suppress
# Out:
# []

# %%
annotations[idx]
# Out:
# ['A 4 5 ||| U:NOUN:POSS |||  ||| REQUIRED ||| -NONE- ||| 0\n']

# %%
sentences[idx]
# Out:
# "And the flying saucers ' culture has dominated . They will be green in color ."

# %%
sentence_dict_1 = {}
sentence_dict_1['S'] = sentences[idx]
sentence_dict_1['A'] = annoations_to_suppress
output_list = supresser_method(sentence_dict_1)
print(*output_list)
# Out:
# And the flying saucers ' culture has dominated . They will be green in color .

# %%
# write a src file
# iterate over sentences file, if index in idx_error_ann_idx, run the supression
# logic if not then just print the sentence

# %%
ordered_idx_error_ann_idx = {k : [k] for k in sorted(idx_error_ann_idx)}

# %%
with open("Output_ru.txt", "w") as text_file:
  for r in range(0, len(sentences)):
    if r in ordered_idx_error_ann_idx.keys():
      #supress logic
      idx = r
      annoations_to_suppress = []
      for x in idx_error_ann_idx[idx]:
        annoations_to_suppress.append(annotations[idx][x].split('|||'))
      sentence_dict_1 = {}
      sentence_dict_1['S'] = sentences[idx]
      sentence_dict_1['A'] = annoations_to_suppress
      output_list = supresser_method(sentence_dict_1)
      str_a = ' '.join(output_list)
      text_file.writelines(str_a + '\n')
      pass
    else:
      #print(sentences[r])
      text_file.writelines(sentences[r] + '\n')

# %%
with open("Source.txt", "w") as text_file:
  for s in sentences:
    text_file.writelines(s + '\n')

# %%
a = ['This', 'job', 'does', "n't", 'demand', 'much', 'ability', ',', 'but', 'a', 'lot', 'of', 'patience', 'though', '.']
str_a = ' '.join(a)
print(str_a)
# Out:
# This job does n't demand much ability , but a lot of patience though .

# %%
'''
# return start_index, end_index, error_type, word(s)
def parse_annotation(annot): 
  a_split = annot.split("|||")

  # get the error type: 
  err_type = a_split[1]

  # get indices
  index_split = a_split[0].split(" ")
  start_index = int(index_split[1])
  end_index = int(index_split[2])

  # get words to replace/remove 
  words = a_split[2].split(" ")

  return start_index, end_index, err_type, words
'''
# Out:
# '\n# return start_index, end_index, error_type, word(s)\ndef parse_annotation(annot): \n  a_split = annot.split("|||")\n\n  # get the error type: \n  err_type = a_split[1]\n\n  # get indices\n  index_split = a_split[0].split(" ")\n  start_index = int(index_split[1])\n  end_index = int(index_split[2])\n\n  # get words to replace/remove \n  words = a_split[2].split(" ")\n\n  return start_index, end_index, err_type, words\n'

# %% [markdown]
# TODO: I don't think this works if the replacement phrase is > than the part of the sentence. also this method doesn't fully work.

# %%
'''
def replace(sent_split, start_index, end_index, words):
  try: 
    for i in range(end_index - start_index):
      if i >= len(words): 
        sent_split[start_index + i + 1] = "" 
      elif start_index + i + 1 >= len(sent_split): 
        sent_split.append(words[i])
      else: 
        sent_split[start_index + i + 1] = words[i]
  except: 
    print("replace failed") 
'''
# Out:
# '\ndef replace(sent_split, start_index, end_index, words):\n  try: \n    for i in range(end_index - start_index):\n      if i >= len(words): \n        sent_split[start_index + i + 1] = "" \n      elif start_index + i + 1 >= len(sent_split): \n        sent_split.append(words[i])\n      else: \n        sent_split[start_index + i + 1] = words[i]\n  except: \n    print("replace failed") \n'

# %%
'''
def missing(sent_split, start_index, end_index, words): 
  for i in range(end_index - start_index): 
    sent_split.insert(start_index + i + 1, words[i]) 
'''
# Out:
# '\ndef missing(sent_split, start_index, end_index, words): \n  for i in range(end_index - start_index): \n    sent_split.insert(start_index + i + 1, words[i]) \n'

# %%
'''
def unnecessary(sent_split, start_index, end_index, words): 
  for i in range(end_index - start_index): 
    # substitute with empty string to prevent indices from changing 
    if start_index + i + 1 < len(sent_split): 
      sent_split[start_index + i + 1] = "" 
'''
# Out:
# '\ndef unnecessary(sent_split, start_index, end_index, words): \n  for i in range(end_index - start_index): \n    # substitute with empty string to prevent indices from changing \n    if start_index + i + 1 < len(sent_split): \n      sent_split[start_index + i + 1] = "" \n'

# %%
'''
def correct_error(sent, annot): 
  start_index, end_index, error_type, words = parse_annotation(annot) 
  sent_split = sent.split(" ")

  # shouldn't be needed but just in case, early termination condition 
  if error_type == "noop": 
    return sent 

  # get R, M, U error type
  err_subtype = error_type.split(":")[0]

  if err_subtype == "R": 
    replace(sent_split, start_index, end_index, words)

  # TODO: fix missing so that it is compatible with further edits 
  elif err_subtype == "M": 
    missing(sent_split, start_index, end_index, words)

  elif err_subtype == "U": 
    unnecessary(sent_split, start_index, end_index, words)

  correct_sent = ' '.join(sent_split) 
  correct_sent = correct_sent.replace("  ", " ")
  return correct_sent 
'''
# Out:
# '\ndef correct_error(sent, annot): \n  start_index, end_index, error_type, words = parse_annotation(annot) \n  sent_split = sent.split(" ")\n\n  # shouldn\'t be needed but just in case, early termination condition \n  if error_type == "noop": \n    return sent \n\n  # get R, M, U error type\n  err_subtype = error_type.split(":")[0]\n\n  if err_subtype == "R": \n    replace(sent_split, start_index, end_index, words)\n\n  # TODO: fix missing so that it is compatible with further edits \n  elif err_subtype == "M": \n    missing(sent_split, start_index, end_index, words)\n\n  elif err_subtype == "U": \n    unnecessary(sent_split, start_index, end_index, words)\n\n  correct_sent = \' \'.join(sent_split) \n  correct_sent = correct_sent.replace("  ", " ")\n  return correct_sent \n'

# %%
'''
sent = 'S I am writing in order to express my disappointment about your musical show " Over the Rainbow " .'
annot = 'A 9 10|||R:PREP|||with|||REQUIRED|||-NONE-|||0|||ca'
print(correct_error(sent, annot))
'''
# Out:
# '\nsent = \'S I am writing in order to express my disappointment about your musical show " Over the Rainbow " .\'\nannot = \'A 9 10|||R:PREP|||with|||REQUIRED|||-NONE-|||0|||ca\'\nprint(correct_error(sent, annot))\n'

# %%
'''
sent = 'S I am writing in order to express my disappointment about your musical show " Over the Rainbow " .'
annot = 'A 9 10|||R:PREP|||with|||REQUIRED|||-NONE-|||0|||ca'
print(correct_error(sent, annot))
'''
# Out:
# '\nsent = \'S I am writing in order to express my disappointment about your musical show " Over the Rainbow " .\'\nannot = \'A 9 10|||R:PREP|||with|||REQUIRED|||-NONE-|||0|||ca\'\nprint(correct_error(sent, annot))\n'

# %%
'''
sent = 'S Maybe you should make have next year ?'
annot = 'A 8 9|||R:PUNCT|||.|||REQUIRED|||-NONE-|||0|||ru'
print(correct_error(sent, annot))
'''
# Out:
# "\nsent = 'S Maybe you should make have next year ?'\nannot = 'A 8 9|||R:PUNCT|||.|||REQUIRED|||-NONE-|||0|||ru'\nprint(correct_error(sent, annot))\n"

# %%
for sent_idx in range(len(sentences)): 

  try: 
    sentence_dict = {}
    sentence_dict['S'] = sentences[sent_idx]
    sentence_dict['A'] = [] 
    for annot_idx in errors_to_suppress[sent_idx]: 
      sentence_dict['A'].append(annotations[sent_idx][annot_idx])
      
    corrected_sentence = supresser_method(sentence_dict)
    #print(corrected_sentence)
    sentences[sent_idx] = " ".join(corrected_sentence)
  except: 
    print("failed")
    continue
# Out:
# Streaming output truncated to the last 5000 lines.
# failed
# ['S', 'Classrooms', ',', 'Lessons', 'and', 'Breaks', '.\n']
# failed
# ['S', 'Obviously', 'it', 'will', 'be', 'interesting', 'to', 'find', 'out', 'what', 'methods', 'are', 'used', 'by', 'our', 'teachers', 'to', 'help', 'pupils', 'understand', 'their', 'subject', 'better', '.\n']
# failed
# failed
# failed
# ['S', 'Outdoor', 'Activities\n']
# failed
# failed
# ['S', 'Conclusion\n']
# failed
# ['S', 'I', 'hope', 'you', 'will', 'consider', 'this', 'information', '.\n']
# ['S', 'Dear', 'Mr', 'Robertson', ',\n']
# failed
# failed
# ['S', 'However', ',', 'there', 'is', 'one', 'point', 'that', 'we', 'would', 'like', 'to', 'change', 'in', 'the', 'programme', '.\n']
# failed
# failed
# ['S', 'Furthermore', 'is', 'totally', 'free', 'for', 'students', '.\n']
# failed
# failed
# failed
# ['S', 'It', 'is', 'also', 'possible', 'to', 'go', 'to', 'the', 'show', 'in', 'the', 'morning', 'but', 'we', 'are', 'totally', 'agree', 'that', 'we', 'do', "n't", 'want', 'to', 'lose', 'our', 'visit', 'to', 'the', 'Science', 'Museum', '.\n']
# failed
# ['S', 'Please', 'contact', 'us', 'if', 'you', 'have', 'any', 'question', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'They', 'use', 'the', 'publicity', 'exclusive', 'for', 'their', 'work', '.\n']
# failed
# failed
# failed
# failed
# ['S', 'Dear', 'Miss', 'Ryan', ',\n']
# ['S', 'I', 'have', 'safely', 'received', 'your', 'letter', 'bringing', 'the', 'good', 'news', '.\n']
# ['S', 'I', 'wish', 'that', 'I', 'could', 'describe', 'how', 'ecstatic', 'I', 'felt', 'when', 'I', 'found', 'that', 'I', 'won', 'the', 'competition', '.\n']
# ['S', 'Here', 'I', 'enclose', 'some', 'information', 'which', 'you', 'requested', 'in', 'the', 'letter', 'I', 'received', '.\n']
# ['S', 'I', 'think', 'that', 'the', 'best', 'and', 'most', 'convenient', 'time', 'for', 'me', 'to', 'travel', 'would', 'be', 'in', 'July', '.\n']
# failed
# ['S', 'This', 'trip', 'will', 'give', 'me', 'a', 'chance', 'to', 'relax', 'during', 'my', 'holidays', ',', 'as', 'well', 'as', 'allow', 'me', 'to', 'gain', 'valuable', 'knowledge', 'and', 'experience', '.\n']
# ['S', 'Between', 'the', 'tent', 'and', 'log', 'cabin', ',', 'I', 'think', 'that', 'I', 'would', 'prefer', 'the', 'tent', '.\n']
# failed
# ['S', 'Living', 'in', 'a', 'tent', 'will', 'also', 'enhance', 'my', 'survival', 'skills', ',', 'making', 'this', 'a', 'trip', 'to', 'remember', '.\n']
# ['S', 'Camp', 'California', 'certainly', 'has', 'plenty', 'of', 'activities', 'to', 'do', '.\n']
# ['S', 'However', ',', 'among', 'all', 'of', 'them', 'I', 'like', 'swimming', 'and', 'tennis', 'the', 'best', '.\n']
# failed
# ['S', 'As', 'for', 'tennis', ',', 'I', 'find', 'it', 'very', 'enjoyable', 'and', 'have', 'gone', 'for', 'proper', 'lessons', '.\n']
# failed
# ['S', 'As', 'I', 'have', 'not', 'been', 'there', 'before', ',', 'I', 'am', 'rather', 'unsure', 'of', 'what', 'to', 'wear', '.\n']
# ['S', 'I', 'am', 'also', 'trying', 'to', 'decide', 'on', 'the', 'amount', 'of', 'money', 'I', 'should', 'bring', '.\n']
# ['S', 'Will', 'I', 'be', 'going', 'out', 'much', ',', 'or', 'just', 'stay', 'in', 'Camp', 'California', 'all', 'the', 'time', '?\n']
# ['S', 'I', 'hope', 'that', 'I', 'have', "n't", 'taken', 'up', 'too', 'much', 'time', '.\n']
# ['S', 'Thank', 'you', 'for', 'this', 'exciting', 'news', '.\n']
# ['S', 'I', 'ca', "n't", 'wait', 'to', 'go', 'on', 'this', 'adventure', 'of', 'a', 'lifetime', '!\n']
# ['S', 'Yours', 'sincerely', ',\n']
# ['S', '(', 'Au', 'Kwan', 'Ming', ')\n']
# ['S', 'Dear', 'Kim', ',\n']
# ['S', 'How', 'are', 'you', 'in', 'London', '?\n']
# ['S', 'I', 'hope', 'the', 'weather', 'is', 'holding', 'up', '.\n']
# ['S', 'I', 'hear', 'that', 'it', 'can', 'be', 'terrible', 'at', 'times', '.\n']
# ['S', 'Guess', 'what', '?\n']
# ['S', 'Last', 'month', ',', 'I', 'got', 'to', 'help', 'out', 'at', 'a', 'pop', 'concert', '.\n']
# ['S', 'It', 'was', 'a', 'fantastic', 'experience', '.\n']
# failed
# ['S', 'All', 'the', 'students', 'had', 'to', 'help', 'to', 'brighten', 'up', 'the', 'place', ',', 'and', 'boy', 'did', 'we', 'work', '.\n']
# ['S', 'I', 'helped', 'to', 'decorate', 'the', 'walls', '.\n']
# ['S', 'My', 'friends', 'and', 'I', 'managed', 'to', 'paint', 'a', 'smart', 'navy', 'blue', 'on', 'the', 'old', ',', 'faded', 'green', '.\n']
# ['S', 'It', 'was', "n't", 'as', 'easy', 'as', 'I', 'had', 'expected', ',', 'there', 'are', 'special', 'equipment', 'and', 'techniques', 'which', 'must', 'be', 'used', 'to', 'ensure', 'a', 'good', 'result', '.\n']
# ['S', 'Besides', 'that', ',', 'I', 'also', 'helped', 'to', 'do', 'banners', 'and', 'signs', 'to', 'inform', 'other', 'people', 'about', 'the', 'concert', '.\n']
# ['S', 'It', 'was', 'hard', 'work', ',', 'I', 'had', 'to', 'saw', 'wood', 'and', 'paint', 'all', 'day', 'long', '.\n']
# ['S', 'Several', 'other', 'students', 'helped', 'me', 'out', ',', 'and', 'we', 'managed', 'to', 'make', 'some', 'eye', '-', 'catching', 'advertisements', '.\n']
# failed
# ['S', 'I', 'fixed', 'the', 'lighting', 'on', 'the', 'ceiling', 'and', 'attached', 'several', 'spotlights', 'to', 'the', 'walls', '.\n']
# ['S', 'This', 'produced', 'a', 'stunning', 'effect', 'during', 'the', 'concert', '.\n']
# failed
# failed
# failed
# failed
# ['S', 'I', 'really', 'enjoyed', 'myself', 'and', 'I', 'hope', 'that', 'you', 'can', 'have', 'the', 'chance', 'to', 'experience', 'this', 'too', '.\n']
# ['S', 'I', 'hope', 'that', 'you', 'can', 'write', 'to', 'me', 'soon', '.\n']
# ['S', 'I', 'look', 'forward', 'to', 'reading', 'what', 'you', 'have', 'to', 'say', '.\n']
# ['S', 'Bye', 'for', 'now', '!\n']
# failed
# ['S', '(', 'Au', 'Kwan', 'Ming', ')\n']
# ['S', 'Dear', 'Ms', 'Helen', 'Ryan\n']
# failed
# ['S', 'I', 'am', 'writing', 'to', 'give', 'you', 'some', 'information', 'about', 'myself', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'Once', 'again', ',', 'thank', 'you', 'for', 'giving', 'me', 'a', 'good', 'opportunity', '.\n']
# failed
# ['S', 'Yours', 'sincerely\n']
# ['S', '(', 'THONGCHAI', 'ENPHENO', ')\n']
# failed
# ['S', 'In', 'the', 'first', 'place', ',', 'some', 'housewifes', 'do', "n't", 'like', 'to', 'go', 'to', 'the', 'supermarket', 'because', 'it', 'is', 'not', 'fun', 'to', 'go', 'shopping', 'with', 'a', 'long', 'list', 'and', 'decide', 'which', 'one', 'is', 'the', 'first', 'and', 'the', 'second', '.\n']
# failed
# ['S', 'It', 'is', 'very', 'frustrating', '.\n']
# ['S', 'Moreover', ',', 'if', 'you', 'go', 'with', 'your', 'children', ',', 'you', 'will', 'have', 'to', 'control', 'them', 'and', 'remember', 'things', 'on', 'your', 'list', 'at', 'the', 'same', 'time', 'and', 'sometimes', 'they', 'cry', 'when', 'they', 'want', 'something', 'in', 'the', 'supermarket', '.\n']
# ['S', 'It', 'is', 'a', 'tough', 'chore', '!\n']
# failed
# failed
# ['S', 'I', 'can', 'not', 'imagine', 'anything', 'worse', '.\n']
# failed
# failed
# failed
# failed
# ['S', 'I', 'am', 'writing', 'from', 'Paris', 'where', 'I', 'live', '.\n']
# failed
# ['S', 'We', 'were', 'really', 'pleased', 'because', 'it', 'was', 'our', 'first', 'time', 'in', 'England', '.\n']
# ['S', 'We', 'asked', 'our', 'travel', 'agent', 'to', 'organise', 'our', 'trip', '.\n']
# failed
# failed
# ['S', 'We', 'were', 'very', 'disappointed', '!\n']
# ['S', 'Of', 'course', ',', 'the', 'show', 'did', "n't", 'start', 'on', 'time', '.\n']
# ['S', 'No', 'reasons', 'or', 'excuses', 'were', 'given', '.\n']
# failed
# ['S', 'But', ',', 'in', 'fact', ',', 'there', 'were', 'no', 'discounts', 'available', '.\n']
# failed
# ['S', 'The', 'worst', 'was', 'to', 'come', '.\n']
# ['S', 'The', 'great', 'Danny', 'Brooks', 'was', 'supposed', 'to', 'be', 'the', 'main', 'character', '.\n']
# failed
# ['S', 'After', 'the', 'show', 'we', 'had', 'planned', 'to', 'go', 'to', 'the', 'theatre', 'restaurant', '.\n']
# ['S', 'But', 'it', 'was', 'closed', '.\n']
# failed
# failed
# ['S', 'Yours', 'faithfully', ',\n']
# ['S', 'And', 'now', ',', 'I', 'was', 'wondering', 'if', 'I', 'had', 'not', 'made', 'a', 'mistake', '.\n']
# ['S', 'My', 'brother', 'was', 'too', 'talkative', '!\n']
# ['S', 'Two', 'days', 'before', ',', 'I', 'told', 'him', 'that', 'our', 'father', 'was', 'about', 'to', 'buy', 'a', 'brand', 'new', 'car', '.\n']
# ['S', 'And', 'he', 'did', 'not', 'want', 'our', 'mother', 'to', 'be', 'informed', '.\n']
# ['S', 'It', 'was', 'supposed', 'to', 'be', 'a', 'gift', 'for', 'twenty', 'years', 'of', 'marriage', '.\n']
# ['S', 'A', 'car', 'only', 'for', 'her', '.\n']
# ['S', 'The', 'first', 'thing', 'Pat', 'did', 'was', 'to', 'tell', 'our', 'young', 'sister', 'the', 'secret', '.\n']
# ['S', 'And', ',', 'less', 'than', 'five', 'minutes', 'later', ',', 'our', 'mother', 'knew', 'the', 'whole', 'thing', '.\n']
# ['S', 'Her', 'reaction', 'was', 'not', 'the', 'one', 'we', 'were', 'expecting', '.\n']
# failed
# ['S', 'Really', 'angry', '!', '!\n']
# ['S', 'She', 'thought', 'it', 'was', 'a', 'stupid', 'idea', ',', 'and', 'also', 'an', 'expensive', 'one', '.\n']
# ['S', 'According', 'to', 'her', ',', 'this', 'car', 'would', 'have', 'been', 'useless', '.\n']
# ['S', 'She', 'suspected', 'our', 'father', 'to', 'want', 'to', 'please', 'himself', '.\n']
# failed
# ['S', 'It', 'was', 'the', 'colour', 'my', 'father', 'had', 'chosen', 'for', 'the', 'car', '!\n']
# ['S', '13.6.00\n']
# ['S', 'Dear', 'Hellen', ',\n']
# failed
# failed
# failed
# failed
# ['S', 'In', 'June', 'I', 'have', 'other', 'arrangements', ',', 'such', 'as', 'my', 'school', 'exams', 'and', 'my', 'birthday', '.\n']
# failed
# ['S', 'After', 'my', 'school', 'exams', 'I', 'will', 'have', 'time', 'to', 'prepare', 'myself', 'for', 'the', 'trip', '.\n']
# failed
# failed
# failed
# failed
# failed
# ['S', 'It', 'is', 'my', 'favourite', 'sport', '.\n']
# ['S', 'I', 'am', 'good', 'and', 'fast', 'at', 'swimming', '.\n']
# failed
# failed
# ['S', 'So', 'we', 'all', 'play', 'as', 'a', 'team', '.\n']
# ['S', 'My', 'final', 'question', 'is', 'this', '.\n']
# failed
# ['S', 'Please', 'give', 'me', 'a', 'rough', 'idea', 'how', 'much', 'spending', 'money', 'I', 'will', 'need', '.\n']
# ['S', 'Please', 'write', 'soon\n']
# ['S', 'Yours', 'Sincerely\n']
# failed
# failed
# ['S', 'Once', 'a', 'week', 'I', 'go', 'shopping', '.\n']
# failed
# failed
# ['S', 'I', 'often', 'shop', 'with', 'no', 'problems', ',', 'but', 'on', 'Saturday', 'is', 'not', 'the', 'same', '.\n']
# failed
# failed
# failed
# ['S', 'I', 'find', 'it', 'very', 'tiring', 'sometimes', '.\n']
# ['S', 'Shopping', 'is', 'not', 'always', 'enjoyable', 'because', 'we', 'spend', 'money', '.\n']
# ['S', 'Usually', 'much', 'more', 'money', 'we', 'spend', 'than', 'we', 'expect', '.\n']
# failed
# failed
# failed
# ['S', 'Dear', 'Sir', 'or', 'Madam\n']
# ['S', 'I', 'have', 'just', 'received', 'your', 'letter', '.\n']
# failed
# ['S', 'First', 'of', 'all', ',', 'I', 'would', 'like', 'to', 'travel', 'in', 'July', 'because', 'I', 'have', 'to', 'return', 'to', 'my', 'University', 'in', 'the', 'middle', 'of', 'August', '.\n']
# failed
# ['S', 'I', 'think', 'it', 'is', 'more', 'comfortable', 'to', 'stay', 'in', 'log', 'cabins', 'than', 'in', 'tents', ',', 'so', 'I', 'would', 'prefer', 'log', 'cabins', '.\n']
# ['S', 'According', 'to', 'your', 'letter', ',', 'I', 'can', 'choose', 'two', 'activities', 'to', 'do', 'at', 'the', 'Camp', '.\n']
# failed
# ['S', 'However', ',', 'I', 'am', 'not', 'very', 'good', 'at', 'playing', 'tennis', ',', 'so', 'could', 'you', 'tell', 'me', 'if', 'I', 'can', 'learn', 'at', 'the', 'camp', '?\n']
# ['S', 'Please', 'could', 'you', 'also', 'let', 'me', 'know', 'if', 'I', 'need', 'to', 'take', 'special', 'clothes', 'with', 'me', '?\n']
# ['S', 'I', 'would', 'be', 'grateful', 'if', 'you', 'phone', 'me', 'or', 'send', 'me', 'a', 'letter', 'again', 'at', 'your', 'earliest', 'convenience', '.\n']
# ['S', 'I', 'look', 'forward', 'to', 'the', 'camp', 'in', 'the', 'U.S.A.\n']
# ['S', 'Yours', 'faithfully\n']
# ['S', 'Cry', 'Freedom\n']
# ['S', "'", 'Cry', 'Freedom', "'", 'is', 'about', 'the', 'blacks', 'and', 'whites', 'of', 'South', 'Africa', '.\n']
# ['S', 'The', 'main', 'characters', 'of', 'this', 'book', 'are', 'Stephen', 'Biko', ',', 'a', 'black', 'leader', ',', 'and', 'Donald', 'Woods', 'who', 'is', 'a', 'white', 'newspaper', 'editor', '.\n']
# failed
# failed
# ['S', 'In', 'some', 'ways', ',', 'he', 'did', 'not', 'agree', 'with', '"', 'Black', 'Consciousness', '"', 'which', 'is', 'Biko', "'s", 'organization', 'because', 'it', 'was', 'too', 'much', 'against', 'the', 'whites', '.\n']
# ['S', 'Woods', 'thought', 'he', 'knew', 'the', 'black', 'society', 'quite', 'well', 'and', 'understood', 'their', 'ordeals', ',', 'but', 'after', 'he', 'had', 'met', 'Biko', 'and', 'visited', 'a', 'black', 'township', ',', 'he', 'realized', 'he', 'had', 'been', 'completely', 'unaware', 'of', 'the', 'way', 'they', 'had', 'to', 'live', '.\n']
# ['S', 'The', 'people', 'and', 'the', 'circumstances', 'he', 'experienced', 'in', 'the', 'black', 'township', 'were', 'such', 'a', 'new', 'world', 'to', 'him', '.\n']
# ['S', 'Finally', 'he', 'changed', 'his', 'ideas', 'and', 'started', 'to', 'work', 'for', 'the', 'blacks', 'using', 'his', 'skill', 'as', 'a', 'journalist', ',', 'in', 'other', 'words', ',', 'he', 'became', 'an', 'activist', 'for', 'the', 'black', 'people', 'of', 'South', 'Africa', '.\n']
# ['S', 'Although', 'Biko', 'was', 'killed', 'and', 'Woods', 'himself', 'was', 'declared', 'a', 'banned', 'person', ',', 'I', 'would', 'dare', 'to', 'say', 'their', 'sacrifices', 'were', 'worthwhile', 'because', 'Woods', 'succeeded', 'in', 'escaping', 'from', 'South', 'Africa', 'which', 'would', 'enable', 'him', 'to', 'publish', 'his', 'book', 'revealing', 'the', 'truth', 'about', 'South', 'Africa', 'to', 'the', 'world', '.\n']
# ['S', 'In', 'short', ',', 'Cry', 'Freedom', 'deserves', 'to', 'be', 'recommended', 'and', 'once', 'you', 'read', 'it', ',', 'you', 'will', 'want', 'to', 'read', 'it', 'again', '.\n']
# ['S', 'Most', 'of', 'all', ',', 'this', 'book', 'will', 'make', 'you', 'think', 'about', 'the', 'prejudice', 'you', 'have', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'Thanking', 'you', ',', 'Yours', 'sincerely', ',', 'Carmen', 'Dolores', 'Rossell\n']
# ['S', 'Dear', 'Kim', ',\n']
# failed
# failed
# failed
# failed
# ['S', 'What', 'I', 'personally', 'liked', 'the', 'most', 'was', 'all', 'our', 'teamwork', '.\n']
# failed
# failed
# ['S', 'Try', 'it', ',', 'I', 'recommend', 'it', '.\n']
# ['S', 'Write', 'back', 'soon', ',\n']
# ['S', 'Love', ',\n']
# ['S', 'Carmen', 'Dolores', 'Rossell', '.\n']
# ['S', 'Dear', 'Sir', ',\n']
# failed
# ['S', 'We', 'were', 'disappointed', 'because', 'your', 'advertisement', 'was', 'a', 'misleading', 'one', '.\n']
# ['S', 'First', 'of', 'all', ',', 'the', 'most', 'important', 'singer', ',', 'Danny', 'Brook', ',', 'was', 'not', 'singing', '.\n']
# failed
# failed
# failed
# ['S', 'The', 'children', 'could', 'not', 'stand', 'waiting', 'outside', 'in', 'the', 'cold', '.\n']
# ['S', 'As', 'it', 'started', 'later', ',', 'it', 'finished', 'later', 'and', 'people', 'missed', 'the', 'train', 'they', 'wanted', 'to', 'take', '.\n']
# failed
# ['S', 'In', 'my', 'opinion', ',', 'the', 'tickets', 'were', 'a', 'little', 'bit', 'expensive', 'and', 'not', 'many', 'people', 'could', 'afford', 'the', 'price', '.\n']
# ['S', 'We', 'did', 'not', 'see', 'any', 'discounts', '!\n']
# failed
# ['S', 'I', 'understand', 'them', '.\n']
# ['S', 'After', 'such', 'a', 'bad', 'show', 'you', 'do', "n't", 'want', 'to', 'eat', 'in', 'the', 'same', 'place', '.\n']
# ['S', 'For', 'these', 'reasons', 'I', 'would', 'like', 'to', 'have', 'my', 'money', 'back', 'because', 'it', 'was', 'not', 'a', '"', 'perfect', 'evening', '"', 'as', 'you', 'said', '.\n']
# failed
# ['S', 'Yours', 'Faithfully\n']
# ['S', 'Modern', 'technology', 'is', 'everywhere', 'in', 'our', 'society', '.\n']
# ['S', 'We', 'use', 'it', 'daily', 'and', 'sometimes', 'do', "n't", 'realize', 'that', 'things', 'are', 'changing', 'in', 'our', 'daily', 'life', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'I', 'chat', 'with', 'other', 'people', 'in', 'order', 'to', 'exchange', 'our', 'points', 'of', 'view', 'or', 'I', 'look', 'for', 'informations', 'I', 'need', 'for', 'my', 'studies', '.\n']
# failed
# ['S', 'Furthermore', 'we', 'can', 'find', 'everything', 'all', 'the', 'time', '.\n']
# failed
# ['S', 'Dear', 'Mr.', 'Smith', ',\n']
# failed
# ['S', 'I', 'went', 'to', 'see', '"', 'Over', 'the', 'rainbow', '"', 'last', 'Saturday', 'and', 'I', 'had', 'a', 'very', 'disappointing', 'evening', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'I', 'am', 'looking', 'forward', 'to', 'hearing', 'from', 'you', 'soon', '.\n']
# failed
# ['S', 'How', 'has', 'modern', 'technology', 'changed', 'your', 'daily', 'life', '?\n']
# failed
# failed
# ['S', 'The', 'day', 'after', 'I', 'get', 'everything', 'at', 'home', 'by', 'post', '.\n']
# failed
# failed
# failed
# ['S', 'You', 'have', 'a', 'lot', 'of', 'things', 'to', 'do', ',', 'to', 'see', ',', 'to', 'learn', '.\n']
# ['S', 'It', 'is', 'too', 'big', 'to', 'tell', 'everybody', 'about', 'what', 'you', 'can', 'do', '!\n']
# failed
# failed
# ['S', 'I', 'hope', 'I', 'will', 'help', 'them', ',', 'I', 'am', 'sure', 'I', 'will', '!\n']
# ['S', 'Dear', 'Sir', 'or', 'Madam', ',\n']
# ['S', 'I', "'m", 'writing', 'to', 'complain', 'about', 'your', 'musical', 'show', '"', 'OVER', 'THE', 'RAINBOW', '"', ',', 'which', 'I', 'recently', 'saw', 'at', 'the', 'Circle', 'Theatre', '.\n']
# failed
# ['S', 'First', 'of', 'all', ',', 'there', 'were', 'no', 'discounts', 'available', ',', 'and', 'having', 'payed', 'Â£20', 'I', 'had', 'to', 'wait', '45', 'minutes', 'longer', 'than', 'expected', 'since', 'the', 'show', 'began', 'at', '20:15', 'and', 'not', 'at', '19:30', '.\n']
# failed
# failed
# failed
# failed
# ['S', 'You', 'see', ',', 'it', 'was', 'not', 'the', '"', 'perfect', 'evening', 'out', '"', ',', 'as', 'you', 'had', 'promised', 'in', 'the', 'advertisement', '.\n']
# ['S', 'Therefor', ',', 'I', 'would', 'like', 'to', 'ask', 'for', 'at', 'least', 'half', 'of', 'my', 'money', 'back', '.\n']
# ['S', 'I', "'m", 'looking', 'forward', 'to', 'hearing', 'from', 'you', 'soon', ',\n']
# ['S', 'Yours', 'faithfully', ',', 'Ewe', 'P', 'Meier\n']
# ['S', 'The', 'pressure', 'of', 'secrets\n']
# ['S', 'Unfortunately', ',', 'Pat', 'was', "n't", 'very', 'good', 'at', 'keeping', 'secrets', '.\n']
# ['S', 'And', 'if', 'he', 'had', 'been', 'able', 'to', 'keep', 'one', ',', 'the', 'following', 'story', 'would', "n't", 'have', 'happened', '.\n']
# failed
# failed
# failed
# ['S', 'What', 'was', 'the', 'reason', '?\n']
# failed
# failed
# failed
# failed
# ['S', 'You', 'see', ',', 'each', 'little', 'secret', 'is', 'a', 'kind', 'of', 'pressure', 'to', 'Pat', ',', 'and', 'he', 'only', 'feels', 'free', 'if', 'he', 'can', 'tell', 'someone', 'about', 'it', '.\n']
# ['S', 'And', 'this', 'is', 'the', 'same', 'for', 'everybody', ',', 'is', "n't", 'it', '?\n']
# ['S', 'Or', 'can', 'you', 'keep', 'a', 'secret', '?\n']
# ['S', 'Dear', 'Mr.', '...\n']
# failed
# failed
# ['S', 'It', "'s", 'not', 'that', 'problem', 'that', 'there', 'was', 'no', 'more', 'discount', 'available', '-\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'Dear', 'Helen', ',\n']
# failed
# failed
# failed
# failed
# ['S', 'Therefore', ',', 'I', 'have', 'chosen', 'golf', 'and', 'tennis', 'from', 'the', 'list', '.\n']
# failed
# ['S', 'I', "'m", 'enjoy', 'playing', 'both', 'of', 'them', 'regularly', '.\n']
# failed
# ['S', 'Finally', ',', 'thank', 'you', 'again', 'for', 'everything', 'and', 'I', 'am', 'looking', 'forward', 'to', 'accompanying', 'you', 'soon', '.\n']
# ['S', 'Yours', 'Sincerely', ',\n']
# ['S', '"', 'Shopping', 'is', 'not', 'always', 'enjoyable', '"', '.\n']
# ['S', 'I', 'think', 'this', 'statement', 'is', 'true', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'Ireland', ',', '16', 'December', '2000\n']
# ['S', 'Dear', 'Mrs', 'Clark', ',\n']
# failed
# ['S', 'I', 'think', 'it', 'is', 'a', 'great', 'idea', 'to', 'have', 'this', 'kind', 'of', 'festival', 'in', 'our', 'region', 'and', 'I', 'really', 'enjoyed', 'most', 'of', 'the', 'events', 'I', 'went', 'to', '.\n']
# ['S', 'However', ',', 'I', 'feel', 'that', 'it', 'could', 'be', 'even', 'better', 'next', 'year', '.\n']
# ['S', 'Firstly', ',', 'according', 'to', 'your', 'advertisement', ',', 'the', "'", 'Stars', 'and', 'artists', 'from', 'around', 'the', 'world', "'", 'came', 'from', 'only', 'six', 'countries', '.\n']
# ['S', 'I', 'felt', 'quite', 'disappointed', 'as', 'everybody', 'knows', 'that', '"', 'our', '"', 'world', 'is', 'full', 'of', 'different', 'cultures', '.\n']
# ['S', 'Maybe', 'not', 'enough', 'were', 'represented', '.\n']
# ['S', 'In', 'spite', 'of', 'the', 'fact', 'that', 'the', 'classical', 'concerts', 'were', 'really', 'good', ',', 'I', 'think', 'that', 'some', 'concert', 'halls', 'were', 'too', 'small', 'and', 'so', 'not', 'everybody', 'could', 'appreciate', 'the', 'good', 'quality', 'of', 'the', 'music', '.\n']
# failed
# ['S', 'I', 'hope', 'so', '!\n']
# failed
# failed
# failed
# ['S', 'I', 'look', 'forward', 'to', 'hearing', 'from', 'you', 'soon', '.\n']
# ['S', 'Yours', 'sincerely', ',\n']
# ['S', 'Dear', 'Magda', ',\n']
# ['S', 'Thanks', 'very', 'much', 'for', 'your', 'letter', '.\n']
# failed
# failed
# ['S', 'I', 'was', 'very', 'surprised', 'when', 'I', 'saw', 'them', 'in', 'your', 'country', '.\n']
# ['S', 'It', 'was', 'a', 'bit', 'funny', 'for', 'me', '.\n']
# failed
# failed
# failed
# failed
# ['S', 'Usually', 'they', 'know', 'what', 'they', "'re", 'allowed', 'to', 'do', 'or', 'not', 'and', 'if', 'they', 'do', "n't", 'respect', 'it', ',', 'the', 'teacher', 'not', 'only', 'punishes', 'them', '(', 'not', 'always', ')', 'but', 'also', 'speaks', 'with', 'them', '.\n']
# ['S', 'At', 'home', 'is', 'different', ',', 'each', 'family', 'has', 'its', 'own', 'rules', '.\n']
# failed
# ['S', 'But', 'I', 'was', 'a', 'wise', 'child', ',', 'so', '!\n']
# ['S', 'Usually', ',', 'at', 'home', ',', 'like', 'at', 'school', ',', 'you', 'have', 'to', 'behave', 'yourself', 'but', 'differently', ',', 'because', 'you', "'re", 'at', 'home', 'so', 'you', 'feel', 'more', 'confident', '.\n']
# failed
# ['S', 'Well', ',', 'I', 'hope', 'I', "'ve", 'helped', 'you', 'a', 'little', 'and', 'I', 'look', 'forward', 'to', 'hearing', 'from', 'you', 'soon', '.\n']
# ['S', 'With', 'lots', 'of', 'love', ',\n']
# ['S', 'Dear', 'Sir', ',\n']
# ['S', 'I', 'am', 'writing', 'to', 'you', 'in', 'reply', 'to', 'your', 'letter', '.\n']
# failed
# ['S', 'I', 'am', 'very', 'excited', 'because', 'I', 'have', 'never', 'won', 'a', 'prize', '.\n']
# failed
# failed
# ['S', 'In', 'August', 'I', 'have', 'to', 'be', 'in', 'Madrid', 'because', 'I', 'am', 'going', 'to', 'work', 'as', 'a', 'trainee', 'in', 'a', 'travel', 'agency', '.\n']
# failed
# failed
# ['S', 'Although', 'all', 'the', 'activities', 'that', 'you', 'mention', 'are', 'very', 'interesting', ',', 'I', 'prefer', 'swimming', 'and', 'tennis', '.\n']
# failed
# ['S', 'I', 'won', 'a', 'local', 'competition', 'when', 'I', 'was', 'seventeen', '.\n']
# failed
# failed
# failed
# failed
# ['S', 'Yours', 'sincerely', ',\n']
# ['S', 'Silvia', 'Torroja', '.\n']
# ['S', 'In', 'my', 'opinion', 'the', 'statement', "'", 'Shopping', 'is', 'not', 'always', 'enjoyable', "'", 'is', 'totally', 'true', '.\n']
# ['S', 'An', 'argument', 'in', 'favour', 'of', 'this', 'statement', 'is', 'that', 'shopping', 'is', 'very', 'tiring', '.\n']
# ['S', 'You', 'can', 'be', 'walking', 'for', 'hours', 'and', 'finally', 'you', 'ca', "n't", 'find', 'anything', 'that', 'you', 'like', '.\n']
# failed
# ['S', 'I', 'think', 'that', 'shopping', 'is', 'even', 'more', 'boring', 'when', 'you', 'go', 'with', 'a', 'friend', 'and', 'you', 'have', 'to', 'give', 'her', 'some', 'advice', '.\n']
# failed
# failed
# ['S', 'I', 'know', 'people', 'who', 'are', 'overdrawn', 'because', 'of', 'shopping', '.\n']
# failed
# ['S', 'So', ',', 'shopping', 'is', 'not', 'enjoyable', ',', 'but', 'necessary', '.\n']
# ['S', 'Dear', 'Mr', 'Robertson', ',\n']
# failed
# ['S', 'It', 'is', 'very', 'various', 'and', 'interesting', '.\n']
# failed
# failed
# failed
# failed
# failed
# ['S', 'The', 'event', 'is', 'a', 'great', 'opportunity', 'because', 'it', 'is', 'on', 'the', '14th', 'of', 'March', 'and', 'it', 'is', 'free', 'for', 'students', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'General', 'speaking', ',', 'homes', 'will', 'change', 'considerably', '.\n']
# failed
# failed
# failed
# failed
# ['S', 'We', 'also', 'will', 'see', 'very', 'high', 'buildings', 'which', 'contains', 'a', 'lot', 'of', 'narrow', 'flats', '.\n']
# failed
# failed
# failed
# ['S', 'New', 'technologies', 'and', 'facilities', 'wo', "n't", 'improve', 'the', 'relationship', 'between', 'people', '.\n']
# failed
# ['S', 'Mr./Mrs', 'Manager', ',\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'Looking', 'forward', 'to', 'receiving', 'your', 'prompt', 'reply', '.\n']
# ['S', 'Sincerely', ',\n']
# ['S', 'How', 'has', 'modern', 'technology', 'changed', 'my', 'daily', 'life', '?\n']
# ['S', 'Well', ',', 'it', "'s", 'pretty', 'simple', 'to', 'answer', 'this', '.\n']
# failed
# failed
# failed
# ['S', 'Nowadays', 'it', 'is', 'a', 'fact', 'that', 'my', 'life', 'would', "n't", 'be', 'the', 'same', 'without', 'my', 'PC', '.\n']
# ['S', 'After', 'I', 'got', 'connected', 'to', 'the', 'Internet', 'my', 'life', 'has', 'completely', 'changed', '.\n']
# ['S', 'I', 'spend', 'my', 'free', 'time', 'building', 'my', 'Personal', 'Web', 'Page', 'with', 'which', 'I', 'intend', 'to', 'earn', 'money', 'in', 'the', 'future', ';', 'and', 'I', 'also', 'check', 'the', 'weather', 'forecast', ',', 'buy', 'food', 'and', 'pay', 'bills', 'through', 'the', 'web', '.\n']
# ['S', 'My', 'daily', 'life', 'would', 'be', 'harder', 'without', 'modern', 'technology', '.\n']
# ['S', 'Mr.', 'Robertson', ':\n']
# failed
# failed
# failed
# failed
# ['S', '.\n']
# ['S', 'Latest', 'Fashions\n']
# ['S', '.\n']
# ['S', 'Leisure', 'and', 'sports', 'wear\n']
# ['S', '.\n']
# failed
# ['S', 'Hairstyles', '.\n']
# ['S', 'On', 'the', 'other', 'hand', ',', 'and', 'the', 'most', 'important', ',', 'it', 'is', 'free', 'for', 'students', '.\n']
# failed
# failed
# failed
# failed
# failed
# ['S', 'A', 'good', 'book', 'should', 'interest', ',', 'amuse', 'or', 'teach', 'the', 'reader', 'something', '.\n']
# failed
# failed
# failed
# ['S', 'It', "'s", 'a', 'detective', 'story', ',', 'like', 'all', 'the', 'stories', 'written', 'by', 'her', '.\n']
# failed
# failed
# failed
# failed
# ['S', 'I', 'read', 'it', 'and', 'I', 'have', 'really', 'enjoyed', 'it', '.\n']
# failed
# ['S', 'Dear', 'Mr', 'Smith', ',\n']
# failed
# failed
# ['S', 'One', 'of', 'the', 'causes', 'of', 'my', 'disappointing', 'was', 'the', 'different', 'actor', 'that', 'played', 'the', 'show', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'For', 'those', 'reasons', 'I', 'ask', 'you', 'for', 'some', 'money', 'back', ',', 'sure', 'of', 'my', 'good', 'reasons', '.\n']
# failed
# ['S', 'Unfortunately', ',', 'Pat', 'was', "n't", 'very', 'good', 'at', 'keeping', 'secrets', '.\n']
# ['S', 'It', "'s", 'for', 'this', 'reason', 'that', 'now', 'I', "'m", 'in', 'this', 'terrible', 'situation', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'I', 'feel', 'sad', 'and', 'shocked', '.\n']
# failed
# failed
# ['S', 'DEAR', '"', 'CIRCLE', 'THEATRE', '"', 'MANAGER', ',\n']
# failed
# ['S', 'THEN', ',', 'THE', 'SHOW', 'WAS', 'TO', 'BEGIN', 'AT', '19:30', ',', 'BUT', 'IT', 'BEGAN', 'ONLY', 'AT', '20.15', '!\n']
# ['S', 'AS', 'REGARDS', 'THE', 'TICKETS', ',', 'I', 'READ', 'THAT', 'DISCOUNTS', 'WERE', 'AVAILABLE', ',\n']
# ['S', 'BUT', 'IT', 'WAS', 'NOT', 'SO', ',\n']
# failed
# failed
# failed
# ['S', 'I', 'HOPE', 'TO', 'HEAR', 'FROM', 'YOU', 'SOON', ',\n']
# ['S', 'BEST', 'WISHES\n']
# ['S', 'FASHION', ':\n']
# ['S', 'THIS', 'TERM', 'EVOKES', 'TOP', 'MODELS', ',', 'STYLISTS', ',', 'COLOURS', 'AND', 'THE', 'GREAT', 'EUROPEAN', 'CAPITAL', 'CITIES', ',', 'LIKE', 'ROME', ',', 'LONDON', 'AND', 'PARIS', '.\n']
# failed
# failed
# failed
# ['S', 'SURELY', ',', 'ORDINARY', 'PEOPLE', 'WILL', 'NOT', 'FOLLOW', 'ONLY', 'THE', 'MODELS', 'PRESENTED', 'ON', 'TV', ',\n']
# failed
# failed
# ['S', 'Dear', 'Madam', ',\n']
# ['S', 'I', 'am', 'very', 'happy', 'to', 'have', 'won', 'first', 'prize', 'in', 'your', 'competition', 'and', 'want', 'to', 'thank', 'you', 'for', 'that', 'very', 'interesting', 'competition', '.\n']
# failed
# ['S', 'But', 'no', 'problem', 'for', 'July', '!\n']
# failed
# failed
# ['S', 'But', 'it', 'does', "n't", 'matter', 'if', 'there', 'is', 'no', 'log', 'cabin', 'available', '...\n']
# ['S', 'Now', 'let', "'s", 'speak', 'about', 'the', 'most', 'interesting', 'activity', ':', 'sport', '.\n']
# failed
# failed
# ['S', 'But', 'if', 'I', 'do', "n't", 'try', 'it', 'I', 'will', 'never', 'know', 'if', 'I', 'like', 'it', 'or', 'not', '!\n']
# failed
# ['S', 'I', 'look', 'forward', 'to', 'hearing', 'from', 'you', '.\n']
# ['S', 'Yours', 'faithfully\n']
# ['S', 'Anis', 'LACOSTE\n']
# ['S', 'We', 'know', 'all', 'what', 'shopping', 'is', '.\n']
# ['S', 'Sometimes', 'it', 'is', 'necessary', 'and', 'sometimes', 'not', 'and', 'overall', 'it', 'is', 'not', 'always', 'enjoyable', '.\n']
# failed
# ['S', 'You', 'think', 'that', 'shopping', 'is', 'not', 'enjoyable', 'at', 'all', '.\n']
# ['S', 'Sometimes', 'it', 'is', 'necessary', 'but', 'you', 'spend', 'four', 'or', 'five', 'hours', 'in', 'the', 'supermarket', 'because', 'there', 'is', 'too', 'much', 'people', '.\n']
# ['S', 'You', 'do', "n't", 'like', 'shopping', 'but', 'you', 'must', 'go', 'shopping', 'to', 'eat', '!\n']
# failed
# failed
# ['S', 'To', 'conclude', ',', 'if', 'you', 'do', "n't", 'want', 'to', 'go', 'to', 'the', 'supermarket', 'to', 'spend', 'four', 'hours', 'there', ',', 'send', 'your', 'girlfriend', 'and', 'it', 'will', 'be', 'more', 'enjoyable', '!\n']
# ['S', 'Dear', 'Mrs.', 'Ryan', ',\n']
# ['S', 'First', 'of', 'all', ',', 'I', 'would', 'like', 'to', 'thank', 'you', 'for', 'this', 'prize', 'and', 'the', 'fact', 'that', 'you', 'wrote', 'me', 'asking', 'for', 'my', 'preferences', 'about', 'the', 'Camp', '.\n']
# failed
# failed
# failed
# failed
# failed
# ['S', 'Please', 'reply', 'soon', '.\n']
# ['S', 'Yours', 'sincerely\n']
# ['S', 'David', 'Brian\n']
# ['S', 'Dear', 'Kim', ',\n']
# ['S', 'You', 'are', 'not', 'going', 'to', 'believe', 'what', 'I', 'am', 'about', 'to', 'tell', 'you', '!\n']
# ['S', 'A', 'couple', 'of', 'months', 'ago', ',', 'I', 'was', 'told', 'that', 'Britney', 'Spears', 'was', 'coming', 'to', 'perform', 'in', 'our', 'city', '.\n']
# failed
# ['S', 'I', 'was', 'really', 'excited', '.\n']
# failed
# ['S', 'And', 'I', 'did', "n't", 'even', 'got', 'paid', '.\n']
# failed
# failed
# failed
# failed
# ['S', 'We', 'talked', 'for', 'about', 'half', 'an', 'hour', 'and', 'when', 'she', 'said', 'goodbye', 'she', 'gave', 'me', 'a', 'kiss', '.\n']
# ['S', 'I', 'wo', "n't", 'forget', 'that', 'moment', 'ever', '.\n']
# failed
# ['S', 'Bye', '.\n']
# ['S', 'With', 'love\n']
# ['S', 'David', 'Brian\n']
# ['S', 'Dear', 'Helen', ',\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'Yours', 'sincerely', ',\n']
# failed
# failed
# failed
# ['S', 'There', 'are', 'a', 'lot', 'of', 'people', 'who', 'spend', 'a', 'lot', 'of', 'money', 'because', 'they', 'like', 'shopping', '.\n']
# failed
# failed
# failed
# failed
# failed
# ['S', 'AUTHORITIES', 'OF', 'THE', 'CIRCLE', 'THEATRE', ':\n']
# ['S', "I'M", 'WRITING', 'YOU', 'BECAUSE', 'I', 'WANT', 'YOU', 'TO', 'KNOW', 'WHAT', 'HAPPENED', 'LAST', 'WEEK', ',', 'WHEN', 'I', 'WENT', 'TO', 'THE', 'CIRCLE', 'THEATRE', 'AND', 'I', 'SAW', '"', 'OVER', 'THE', 'RAINBOW', '"', '.\n']
# ['S', 'IT', 'WAS', 'REALLY', 'DISAPPOINTING', '.\n']
# failed
# failed
# ['S', 'SECONDLY', '...\n']
# failed
# ['S', 'WHEN', 'IT', 'STARTED', 'I', 'COULD', 'SEE', 'THAT', 'DANNY', 'BROOK', "WASN'T", 'IN', 'THE', 'PLAY', ',', 'AND', 'NOBODY', 'TOLD', 'US', 'WHY', '.\n']
# ['S', 'THE', 'ACTOR', 'WHO', 'WAS', 'ACTING', 'HIS', 'PART', 'IS', 'THE', 'WORST', 'I', 'HAVE', 'EVER', 'SEEN', ',', 'REALLY', 'TERRIBLE', '.\n']
# ['S', 'HE', 'HAD', 'BEEN', 'IN', 'A', 'PLAY', 'BEFORE', '?\n']
# ['S', 'I', "DON'T", 'THINK', 'SO', '....\n']
# ['S', 'FINALLY', ',', 'WHEN', 'THE', 'PLAY', 'FINISHED', ',', 'WE', 'WENT', 'TO', 'THE', 'THEATRE', 'RESTAURANT', 'TO', 'HAVE', 'DINNER', 'BUT', 'IT', 'WAS', 'CLOSED', '.\n']
# failed
# failed
# failed
# failed
# failed
# ['S', 'YOURS', 'SINCERELY', '.\n']
# ['S', 'UNFORTUNATELY', ',', 'PAT', "WASN'T", 'VERY', 'GOOD', 'AT', 'KEEPING', 'SECRETS', '....\n']
# failed
# failed
# ['S', 'HAD', 'HEARD', 'THE', 'RUMOUR', '.\n']
# ['S', 'HE', 'ASKED', 'MARIA', 'IF', 'IT', 'WAS', 'TRUE', 'AND', 'SHE', "COULDN'T", 'LIE', '.\n']
# ['S', 'HE', 'GOT', 'VERY', 'ANGRY', 'AND', 'HE', "DIDN'T", 'ALLOW', 'MARIA', 'GOING', 'OUT', 'FOR', 'A', 'PERIOD', 'OF', 'TWO', 'WEEKS', '.\n']
# ['S', 'MARIA', 'TALKED', 'TO', 'HER', 'FATHER', 'AND', 'TRIED', 'TO', 'EXPLAIN', 'HIM', 'THAT', 'TIM', 'IS', 'A', 'GOOD', 'PERSON', 'BUT', 'HER', 'FATHER', 'SAYS', 'THAT', 'SHE', 'IS', 'TOO', 'YOUNG', 'TO', 'HAVE', 'A', 'BOYFRIEND', '.\n']
# ['S', 'MARIA', 'MET', 'TIM', 'AT', 'NIGHT', ',', 'WHEN', 'HER', 'FATHER', 'WAS', 'SLEEPING', '.\n']
# failed
# failed
# ['S', 'MARIA', 'IS', 'STILL', 'GOING', 'OUT', 'WITH', 'TIM', '.\n']
# failed
# ['S', 'Dear', '...\n']
# ['S', 'Thanks', 'for', 'your', 'letter', '.\n']
# failed
# failed
# failed
# failed
# failed
# ['S', 'I', 'like', 'to', 'singing', 'a', 'song', 'when', 'I', 'am', 'alone', '.\n']
# failed
# failed
# failed
# failed
# failed
# ['S', 'Do', 'I', 'need', 'a', 'lot', 'of', 'money', 'etc', '.\n']
# failed
# ['S', 'Thanks', 'for', 'your', 'answer', '.\n']
# failed
# ['S', 'Shopping', 'is', 'not', 'always', 'enjoyable\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'Dear', 'Sir', '/', 'Madam', ',\n']
# failed
# failed
# failed
# ['S', 'Moreover', ',', 'he', 'made', 'many', 'mistakes', '.\n']
# failed
# failed
# ['S', 'The', 'show', 'supposed', 'to', 'start', 'at', '19:30', ',', 'but', 'it', 'started', 'at', '20:15', '.\n']
# ['S', 'Because', 'of', 'that', ',', 'we', 'missed', 'the', 'train', 'and', 'we', 'had', 'to', 'stay', 'one', 'more', 'night', 'in', 'London', '.\n']
# failed
# failed
# ['S', 'I', 'would', 'recommend', 'you', 'to', 'show', 'that', 'the', 'restaurant', 'is', 'closed', 'on', 'Monday', '.\n']
# ['S', 'I', 'could', 'not', 'have', 'dinner', '.\n']
# ['S', 'I', 'look', 'forward', 'to', 'hearing', 'from', 'you', 'soon', '.\n']
# ['S', 'Yours', 'faithfully', ',\n']
# ['S', 'Fashion', 'of', 'the', 'Future\n']
# failed
# failed
# failed
# failed
# failed
# ['S', 'I', 'suppose', 'that', 'a', 'scientist', 'could', 'invent', 'new', 'kinds', 'of', 'materials', 'which', 'are', 'warm', 'and', 'thick', '.\n']
# ['S', 'It', 'could', 'be', 'happened', 'that', 'people', 'wear', 'the', 'clothes', 'which', 'ancient', 'people', 'used', 'to', 'wear', ',', 'like', 'skirts', 'made', 'of', 'leaves', '.\n']
# failed
# failed
# failed
# ['S', 'However', ',', 'fashion', 'changes', 'too', 'fast', 'to', 'predict', '.\n']
# ['S', 'I', 'think', 'fashion', 'changes', 'very', 'quickly', 'so', 'that', 'people', 'are', 'interested', 'in', 'those', 'changes', '.\n']
# ['S', 'Dear', 'Mr', 'Robertson\n']
# failed
# failed
# ['S', 'All', 'our', 'class', 'like', 'to', 'see', 'the', 'beautiful', 'pictures', 'which', 'were', 'drawn', 'by', 'brilliant', 'artists', 'and', 'painters', '.\n']
# ['S', 'We', 'saw', 'an', 'advertisement', 'for', 'the', 'London', 'Fashion', 'and', 'Leisure', 'Show', 'and', 'our', 'class', 'would', 'like', 'to', 'go', 'to', 'the', 'show', '.\n']
# ['S', 'It', 'starts', 'on', 'Tuesday', 'March', '14', 'and', 'we', 'can', 'go', 'there', 'instead', 'of', 'visiting', 'the', 'Science', 'Museum', 'or', 'go', 'shopping', '.\n']
# failed
# failed
# failed
# ['S', 'You', 'know', 'what', 'else', '?\n']
# failed
# failed
# failed
# failed
# failed
# ['S', 'Thank', 'you', 'very', 'much', '.\n']
# failed
# ['S', 'Hello\n']
# ['S', 'I', "'m", 'going', 'to', 'write', 'about', '"', 'The', 'Home', 'of', 'the', 'Future', '"', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'Now', 'what', "'s", 'going', 'to', 'be', 'the', 'same', '.\n']
# failed
# failed
# failed
# failed
# ['S', 'Bye', '.\n']
# ['S', 'Elise', '-', 'Lune', '48\n']
# ['S', '1093', 'La', 'Conversion\n']
# ['S', '17th', 'June', '2000\n']
# ['S', 'The', 'Manager', 'of\n']
# ['S', 'The', 'Circle', 'Theatre\n']
# ['S', 'Dear', 'Sir', ',\n']
# failed
# ['S', 'and', 'I', 'had', 'a', 'disappointing', 'evening', '.\n']
# failed
# failed
# failed
# failed
# ['S', 'That', "'s", 'why', 'I', 'ask', 'you', 'to', 'give', 'my', 'money', 'back', '.\n']
# failed
# ['S', 'I', "'m", 'looking', 'forward', 'to', 'hearing', 'from', 'you', '.\n']
# ['S', 'How', 'has', 'modern', 'technology', 'changed', 'your', 'daily', 'life', '?\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'We', 'use', 'every', 'day', 'technological', 'machines', 'without', 'to', 'know', '.\n']
# failed
# ['S', 'Dear', 'Ms', 'Clark', ',\n']
# failed
# failed
# failed
# ['S', 'That', 'was', 'disappointing', '!\n']
# failed
# ['S', 'What', 'about', 'plays', 'and', 'films', '?\n']
# failed
# ['S', 'But', 'do', 'not', 'worry', '!\n']
# failed
# ['S', 'The', 'reasonably', '-', 'priced', 'weekend', 'ticket', 'was', 'a', 'very', 'good', 'idea', '.\n']
# failed
# failed
# failed
# ['S', 'Best', 'regards\n']
# failed
# failed
# ['S', 'There', 'are', 'also', 'some', 'schools', 'which', 'offer', 'such', 'a', 'job', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'Not', 'everybody', 'has', 'the', 'ability', 'to', 'understand', 'everything', 'at', 'once', '.\n']
# failed
# failed
# failed
# failed
# failed
# ['S', 'In', 'my', 'free', 'time', 'I', 'like', 'to', 'play', 'golf', 'and', 'swim', ',', 'so', 'I', 'think', 'that', 'I', "'m", 'good', 'playing', 'golf', '.\n']
# failed
# failed
# failed
# failed
# failed
# ['S', 'Shopping', 'is', 'not', 'always', 'enjoyable\n']
# failed
# failed
# failed
# ['S', 'Dear', 'Sir', '/', 'Madam\n']
# failed
# failed
# failed
# ['S', 'The', 'first', 'is', 'time', '.\n']
# failed
# ['S', 'The', 'second', 'is', 'accommodation', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'There', 'is', 'one', 'more', 'thing', 'which', 'I', 'would', 'like', 'to', 'know', 'about', '.\n']
# failed
# failed
# ['S', 'And', 'of', 'course', 'there', 'will', 'be', 'expenses', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'And', 'what', 'you', 'have', '.\n']
# failed
# failed
# failed
# ['S', 'It', 'takes', 'hours', 'to', 'buy', 'something', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'Dear', 'Ryan\n']
# failed
# ['S', 'I', 'am', 'writing', 'to', 'inform', 'you', 'my', 'preferences', 'and', 'ask', 'a', 'few', 'questions', 'about', 'the', 'camping', '.\n']
# failed
# ['S', 'I', 'have', 'discussed', 'it', 'with', 'my', 'boss', 'but', 'he', 'allowed', 'me', 'to', 'go', 'on', 'a', 'holiday', 'only', 'in', 'July', '.\n']
# ['S', 'And', 'about', 'accommodation', ',', 'I', 'would', 'like', 'to', 'stay', 'in', 'a', 'tent', '.\n']
# failed
# failed
# failed
# ['S', 'Photography', 'is', 'one', 'of', 'my', 'hobbies', 'so', 'I', 'want', 'to', 'take', 'nice', 'photos', 'in', 'the', 'camp', 'area', 'as', 'many', 'as', 'I', 'can', '.\n']
# ['S', 'I', 'would', 'like', 'to', 'know', 'about', 'the', 'weather', 'in', 'the', 'camp', 'area', 'because', 'I', 'do', "n't", 'know', 'what', 'kinds', 'of', 'clothes', 'I', 'have', 'to', 'bring', '.\n']
# failed
# failed
# ['S', 'Thank', 'you', 'for', 'your', 'kindness', 'and', 'I', 'look', 'forward', 'to', 'your', 'reply', '.\n']
# ['S', 'Yours', 'sincerely', ',\n']
# ['S', 'Clark', '.\n']
# ['S', 'Dear', 'Helen', ',\n']
# failed
# failed
# failed
# failed
# ['S', 'I', 'have', 'always', 'loved', 'camping', '.\n']
# ['S', 'My', 'favourite', 'hobby', 'is', 'photography', 'and', 'I', 'think', 'I', 'am', 'very', 'good', 'at', 'it', '.\n']
# ['S', 'I', 'have', 'been', 'taking', 'photographs', 'since', 'I', 'was', '17', '.\n']
# failed
# failed
# failed
# ['S', 'Also', ',', 'I', 'have', 'some', 'questions', '.\n']
# ['S', 'I', 'have', 'never', 'been', 'to', 'California', 'before', 'so', 'I', 'have', 'no', 'idea', 'about', 'the', 'climate', '.\n']
# ['S', 'Could', 'you', 'please', 'give', 'me', 'some', 'information', 'about', 'it', 'and', 'what', 'kind', 'of', 'clothes', 'should', 'I', 'bring', 'for', 'my', 'holiday', '.\n']
# failed
# ['S', 'Is', 'it', 'an', 'expensive', 'city', '?\n']
# failed
# ['S', 'I', 'look', 'forward', 'to', 'hearing', 'from', 'you', '.\n']
# ['S', 'Yours', 'sincerely', ',\n']
# ['S', 'Dear', 'Kim', ',\n']
# ['S', 'I', 'am', 'so', 'sorry', 'that', 'I', 'could', "n't", 'write', 'you', 'last', 'week', '.\n']
# ['S', 'As', 'you', 'know', ',', 'I', 'was', 'very', 'busy', 'and', 'excited', 'about', 'a', 'pop', 'concert', 'which', 'I', 'worked', 'as', 'a', 'director', "'s", 'assistant', 'during', 'the', 'last', 'week', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'She', 'was', 'very', 'nice', 'and', 'friendly', '.\n']
# failed
# failed
# ['S', 'I', 'met', 'lots', 'of', 'people', 'who', 'were', 'very', 'famous', '.\n']
# failed
# ['S', 'We', 'promised', 'each', 'other', 'to', 'keep', 'in', 'touch', 'and', 'she', 'has', 'invited', 'me', 'her', 'next', 'concert', '!\n']
# failed
# failed
# ['S', 'Love', 'from', ',\n']
# failed
# ['S', 'Thank', 'you', 'for', 'my', 'prize', '!\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'See', 'you', 'soon', '!\n']
# failed
# ['S', '"', 'Shopping', 'is', 'not', 'always', 'enjoyable', '"', '"', 'Shopping', 'today', '!\n']
# failed
# failed
# ['S', 'That', "'s", 'why', 'it', 'should', 'be', 'a', 'great', 'day', '!\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'What', 'is', 'going', 'on', '?', '?\n']
# ['S', 'So', ',', 'you', "'d", 'better', 'to', 'stay', 'home', 'today', '...\n']
# failed
# failed
# ['S', 'I', 'went', 'to', 'a', 'performance', 'and', 'I', 'am', 'very', 'disappointed', '.\n']
# ['S', 'Firstly', ',', 'your', 'advertisement', 'said', 'the', 'actor', 'would', 'be', 'Danny', 'Brook', ',', 'but', 'it', 'was', 'not', '.\n']
# failed
# failed
# failed
# ['S', 'Did', 'you', 'know', 'that', 'you', 'have', 'no', 'discounts', 'on', 'your', 'tickets', '?\n']
# ['S', 'I', 'could', 'not', 'believe', 'that', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'Pica', 'Landen\n']
# ['S', "'", 'Fashion', 'of', 'the', 'Future', "'", '!\n']
# failed
# failed
# ['S', 'I', 'think', 'it', 'is', 'important', 'and', 'necessary', 'to', 'think', 'about', 'it', ',', 'because', 'our', 'children', 'will', 'live', 'in', 'the', 'future', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'They', 'just', 'look', 'funny', '!\n']
# ['S', 'See', 'you', 'in', 'your', 'next', 'life', '!\n']
# ['S', 'Dear', 'Helen', 'Ryan\n']
# failed
# ['S', 'It', 'is', 'a', 'pleasure', 'for', 'me', '.\n']
# failed
# failed
# failed
# failed
# ['S', 'Another', 'question', 'that', 'you', 'asked', 'me', 'was', 'about', 'two', 'activities', 'I', 'will', 'have', 'the', 'chance', 'to', 'do', 'there', '.\n']
# failed
# failed
# ['S', 'I', 'would', 'like', 'to', 'know', 'something', 'about', 'money', 'and', 'clothes', '.\n']
# failed
# ['S', 'How', 'much', 'money', 'I', 'can', 'spent', 'during', 'this', 'time', '?\n']
# failed
# ['S', 'I', 'am', 'look', 'forward', 'to', 'hearing', 'from', 'you\n']
# ['S', 'Yours', 'sincerely\n']
# ['S', 'Rui', 'Veloso\n']
# ['S', 'Dear', 'Kim', ',\n']
# ['S', 'I', 'am', 'very', 'happy', 'with', 'your', 'letter', 'that', 'I', 'received', 'last', 'week', '.\n']
# failed
# failed
# ['S', 'It', 'was', 'a', 'marvellous', 'concert', 'and', 'there', 'were', 'about', '100,000', 'people', 'there', '.\n']
# failed
# failed
# ['S', 'I', 'met', 'Madonna', 'and', 'could', 'talk', 'with', 'her', 'for', 'ten', 'minutes', '.\n']
# failed
# failed
# failed
# ['S', 'I', 'said', '"', 'yes', '"\n']
# ['S', 'and', 'I', 'am', 'sure', 'it', 'was', 'the', 'best', 'decision', 'of', 'my', 'life', '.\n']
# ['S', 'Of', 'course', 'I', 'was', 'very', 'tired', 'at', 'the', 'end', 'of', 'five', 'days', 'because', 'of', 'some', 'stressed', 'situations', '.\n']
# failed
# ['S', 'Hope', 'to', 'hearing', 'from', 'you', 'soon\n']
# ['S', 'With', 'best', 'wishes', ',\n']
# ['S', 'Rui\n']
# ['S', 'Dear', 'Mr./Mrs', ':\n']
# failed
# ['S', 'I', 'am', 'very', 'excited', 'about', 'it', '!\n']
# failed
# failed
# failed
# ['S', 'I', 'will', 'take', 'my', 'sleeping', 'bag', 'with', 'me', ',', 'just', 'in', 'case', '.\n']
# ['S', 'I', 'would', 'love', 'to', 'participate', 'in', 'the', 'singing', 'and', 'photography', 'activities', '.\n']
# ['S', 'Singing', 'is', 'something', 'I', 'have', 'enjoyed', 'since', 'I', 'was', 'a', 'little', 'child', '.\n']
# ['S', 'In', 'fact', ',', 'I', 'took', 'some', 'singing', 'lessons', '.\n']
# ['S', 'I', 'am', 'not', 'very', 'good', 'at', 'photography', 'but', 'I', 'want', 'to', 'make', 'an', 'album', 'to', 'share', 'it', 'with', 'my', 'family', 'when', 'I', 'come', 'home', '.\n']
# failed
# ['S', 'How', 'much', 'money', 'will', 'I', 'need', '?\n']
# ['S', 'Is', 'it', 'better', 'to', 'take', 'cash', 'or', 'a', 'credit', 'card', '?\n']
# ['S', 'Thanks', 'for', 'your', 'attention', '.\n']
# failed
# ['S', 'Shopping', 'is', 'not', 'always', 'enjoyable\n']
# failed
# ['S', 'If', 'people', 'would', 'think', 'about', 'it', 'BEFORE', 'going', 'shopping', ',', 'they', 'would', 'not', 'have', 'a', 'headache', 'when', 'they', 'go', 'home', 'and', 'realize', 'they', 'did', 'not', 'want', 'what', 'they', 'bought', '.\n']
# ['S', 'Shopping', 'can', 'be', 'an', 'awful', 'adventure', 'when', 'people', 'want', 'to', 'buy', 'all', 'their', 'presents', 'the', 'day', 'before', 'Christmas', ',', 'for', 'example', '.\n']
# ['S', 'There', 'is', 'no', 'way', 'to', 'find', 'good', 'prices', '!\n']
# ['S', 'Shops', 'are', 'crowded', ',', 'items', 'are', 'of', 'bad', 'quality', 'and', 'people', 'are', 'buying', 'without', 'thinking', '.\n']
# failed
# failed
# ['S', 'Recommendations', '?\n']
# failed
# ['S', '13', 'of', 'June', '2000\n']
# ['S', 'Dear', 'Helen', 'Ryan', ':\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'Yours', 'sincerely\n']
# ['S', 'Dear', 'Kim', ':\n']
# failed
# failed
# failed
# ['S', 'We', 'was', 'so', 'close', 'to', 'him', ',', 'I', 'did', "n't", 'have', 'the', 'chance', 'to', 'talk', 'with', 'him', 'but', 'I', 'do', "n't", 'mind', ',', 'I', 'will', 'never', 'forget', 'that', 'day', '.\n']
# failed
# failed
# ['S', 'lots', 'of', 'love\n']
# ['S', 'Saturday', ',', 'June', '17th', ',', '2000', '.\n']
# ['S', 'Dear', 'Sir', 'or', 'Madam', ',\n']
# failed
# failed
# failed
# failed
# ['S', 'Then', ',', 'to', 'complete', 'this', 'terrible', 'night', ',', 'the', 'restaurant', 'was', 'closed', '.\n']
# ['S', 'I', 'wonder', 'you', 'could', 'explain', 'me', 'why', '.\n']
# failed
# ['S', 'I', 'look', 'forward', 'to', 'hearing', 'from', 'you', '.\n']
# ['S', 'Yours', 'faithfully', ',\n']
# ['S', 'MANUELA', 'REVES', 'RAVERNO\n']
# ['S', 'The', 'influence', 'of', 'modern', 'technology\n']
# failed
# ['S', 'Today', ',', 'almost', 'no', 'one', 'can', 'live', 'without', ',', 'for', 'example', ',', 'a', 'television', ',', 'a', 'radio', 'or', 'electricity', 'in', 'their', 'homes', '.\n']
# failed
# ['S', 'Without', 'leaving', 'my', 'bedroom', ',', 'I', 'can', 'go', 'anywhere', 'using', 'the', 'Internet', '.\n']
# failed
# failed
# failed
# ['S', 'Dear', 'Sir', '/', 'Madam', ',\n']
# failed
# ['S', 'Firstly', ',', 'I', 'would', 'like', 'to', 'say', 'that', 'I', 'am', 'very', 'disappointed', 'and', 'upset', 'with', 'the', 'show', 'I', 'saw', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'The', 'only', 'thing', 'to', 'do', 'is', ':', 'to', 'compensate', 'me', ',', 'send', 'my', 'money', 'back', ',', 'I', 'am', 'sending', 'my', 'ticket', 'for', 'that', ':\n']
# ['S', 'Hope', 'you', "'ll", 'be', 'fair', 'with', 'me', 'otherwise', 'I', 'am', 'going', 'to', 'take', 'this', 'further', '.\n']
# ['S', 'I', 'look', 'forward', 'to', 'hearing', 'from', 'you', 'soon', '.\n']
# ['S', 'Yours', 'faithfully\n']
# ['S', 'MÃ¡rcia\n']
# ['S', '"', 'Techno', 'life', '"\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'Dear', 'Mrs', 'Ryan', ',\n']
# ['S', 'Thanks', 'for', 'your', 'letter', '.\n']
# ['S', 'I', 'have', 'reading', 'the', 'letter', 'and', 'I', 'was', 'very', 'surprised', 'that', 'I', 'have', 'won', 'the', 'first', 'prize', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'In', 'the', 'summer', 'I', "'m", 'sailing', 'races', 'almost', 'every', 'weekend', 'and', 'I', 'have', 'my', 'own', 'sailing', 'clothes', '.\n']
# failed
# ['S', 'Finally', ',', 'I', 'have', 'one', 'question', 'about', 'the', 'money', '.\n']
# failed
# ['S', 'Yours', 'sincerely', ',\n']
# ['S', 'Dear', 'Kim', ',\n']
# ['S', 'Thanks', 'for', 'your', 'letter', '.\n']
# ['S', 'How', 'are', 'you', '?\n']
# ['S', 'With', 'me', 'is', 'everything', 'fine', 'and', 'the', 'pop', 'concert', 'was', 'great', '.\n']
# failed
# ['S', 'You', 'always', 'walk', 'from', 'side', 'to', 'side', 'to', 'move', 'things', 'and', 'there', "'s", 'no', 'break', '.\n']
# failed
# ['S', 'We', 'have', 'worked', 'the', 'whole', 'day', 'and', 'luckily', 'at', 'least', 'we', 'had', 'some', 'food', '.\n']
# failed
# failed
# ...
# failed
# ['S', 'Fashion', 'news', 'are', 'followed', 'by', 'lots', 'of', 'people', '.\n']
# ['S', 'We', 'want', 'to', 'know', 'what', 'we', 'will', 'have', 'to', 'wear', 'next', 'year', 'but', 'we', 'want', 'to', 'know', 'it', 'now', '.\n']
# ['S', 'But', 'have', 'you', 'thought', 'about', 'what', 'kind', 'of', 'clothes', 'we', 'will', 'wear', '100', 'years', 'from', 'now', '?\n']
# failed
# failed
# failed
# ['S', 'Another', 'important', 'thing', 'will', 'be', 'the', 'use', 'of', 'technology', '.\n']
# failed
# failed
# failed
# failed
# failed
# ['S', 'The', 'International', 'Arts', 'Festival', 'is', 'a', 'beautiful', 'idea', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'It', "'s", 'a', 'story', 'of', 'a', 'special', 'person', 'who', 'was', 'born', 'in', 'my', 'country', 'and', 'who', 'is', 'now', 'known', 'worldwide', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'Dear', 'Sir', '/', 'Madam', ',\n']
# ['S', 'I', 'am', 'writing', 'to', 'complain', 'about', 'the', 'musical', "'", 'OVER', 'THE', 'RAINBOW', "'", '.\n']
# ['S', 'There', 'were', 'some', 'unfortunate', 'incidents', '.\n']
# failed
# ['S', 'However', ',', 'I', 'could', 'not', 'get', 'them', '.\n']
# failed
# ['S', 'In', 'addition', 'to', 'this', ',', 'the', 'show', 'was', 'supposed', 'to', 'start', 'at', '19.30', ',', 'but', 'it', 'started', 'at', '20.15', '.\n']
# ['S', 'As', 'a', 'result', ',', 'I', 'could', 'not', 'visit', 'the', 'restaurant', 'since', 'it', 'had', 'already', 'closed', 'when', 'the', 'show', 'finished', '.\n']
# failed
# failed
# ['S', 'Can', 'you', 'imagine', 'how', 'upset', 'I', 'was', '?\n']
# failed
# failed
# ['S', 'Yours', 'faithfully', ',\n']
# failed
# ['S', 'To', 'begin', 'with', ',', 'I', 'think', 'the', 'mobile', 'phone', 'is', 'very', 'useful', 'because', 'I', 'can', 'make', 'a', 'phone', 'call', 'wherever', 'I', 'am', ',', 'without', 'looking', 'for', 'a', 'telephone', 'box', '.\n']
# failed
# failed
# ['S', 'Secondly', ',', 'as', 'far', 'as', 'I', 'am', 'concerned', ',', 'the', 'computer', 'is', 'a', 'great', 'invention', '.\n']
# failed
# ['S', 'Since', 'I', 'bought', 'a', 'computer', ',', 'I', 'have', 'been', 'checking', 'E', '-', 'mails', 'from', 'my', 'friend', 'almost', 'every', 'day', '.\n']
# failed
# failed
# ['S', '17th', 'June', '2000\n']
# ['S', 'Dear', 'Sir', ',\n']
# failed
# ['S', 'But', 'it', 'turned', 'out', ',', 'it', 'really', 'was', "n't", 'a', 'pleasant', 'evening', ',', 'and', 'I', 'did', "n't", 'enjoy', 'myself', '.\n']
# ['S', 'On', 'top', 'of', 'this', ',', 'the', 'advertisement', 'was', "n't", 'correct', 'at', 'all', ',', 'or', 'I', 'must', 'have', 'been', 'to', 'the', 'wrong', 'show', '!\n']
# ['S', 'According', 'to', 'the', 'advertisement', ',', 'the', 'show', 'should', 'have', 'started', 'at', '19.30', ',', 'but', 'it', 'did', "n't", 'begin', 'before', '20.15', '.\n']
# ['S', 'That', "'s", 'nearly', 'an', 'hour', 'later', '!\n']
# failed
# ['S', 'They', 'had', 'never', 'heard', 'of', 'such', 'a', 'thing', '!\n']
# ['S', 'The', 'actors', 'were', 'not', 'the', 'ones', 'expected', ':', 'there', 'was', 'no', 'sign', 'of', 'Danny', 'Brook', ',', 'and', 'the', 'person', 'who', 'played', 'his', 'part', 'was', 'very', 'disappointing', '.\n']
# failed
# ['S', 'In', 'conclusion', ',', 'I', 'was', "n't", 'at', 'all', 'satisfied', ',', 'and', 'I', 'would', 'like', 'my', 'money', 'back', 'since', 'the', 'show', 'was', "n't", 'worth', 'it', '.\n']
# ['S', 'Yours', 'sincerely\n']
# ['S', 'Unfortunately', ',', 'Pat', 'was', "n't", 'very', 'good', 'at', 'keeping', 'secrets', '..\n']
# ['S', 'But', 'I', 'found', 'out', 'afterwards', 'and', 'it', 'was', 'too', 'late', '.\n']
# failed
# failed
# ['S', 'No', 'one', 'knew', 'apart', 'from', 'me', 'and', 'my', 'mother', '.\n']
# ['S', 'I', 'kept', 'lying', 'when', 'somebody', 'asked', 'where', 'my', 'dad', 'was', '.', '"\n']
# failed
# failed
# ['S', 'Since', 'everyone', 'knew', 'the', 'truth', ',', 'things', 'were', "n't", 'the', 'same', '.\n']
# ['S', 'Everyone', ',', 'even', 'my', 'friends', ',', 'looked', 'at', 'me', 'in', 'a', 'strange', 'kind', 'of', 'way', '.\n']
# ['S', 'As', 'if', 'I', 'was', 'guilty', '.\n']
# ['S', 'What', 'did', 'I', 'have', 'to', 'do', 'with', 'this', '?\n']
# ['S', 'I', 'was', "n't", 'the', 'one', 'who', 'had', 'killed', 'the', 'man', ',', 'but', 'it', 'seemed', 'people', 'did', "n't", 'want', 'to', 'talk', 'to', 'me', 'anymore', '.\n']
# failed
# ['S', 'Dear', 'Madam\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'I', 'have', 'one', 'question', 'to', 'ask', 'you', '.\n']
# failed
# ['S', 'He', 'does', "n't", 'like', 'stay', 'alone', 'at', 'home', '.\n']
# ['S', 'Yours', 'faithfully\n']
# ['S', 'Anton', 'Chevalier\n']
# failed
# failed
# failed
# failed
# failed
# ['S', '-', 'During', 'the', 'break', 'we', 'could', 'show', 'the', 'activities', 'of', 'the', 'students', '.\n']
# failed
# ['S', 'We', 'could', 'asked', 'some', 'students', 'about', 'the', 'school', '.\n']
# ['S', '-', 'Before', 'the', 'end', 'we', 'could', 'visit', 'the', 'staff', 'room', '.\n']
# failed
# failed
# ['S', 'Anton', 'Chevalier\n']
# ['S', 'Dear', 'Mr.', 'Ryan\n']
# ['S', 'Thank', 'you', 'for', 'your', 'letter', '.\n']
# ['S', 'I', 'have', 'just', 'received', 'the', 'letter', 'from', 'you', '.\n']
# failed
# ['S', 'I', 'would', 'like', 'to', 'travel', 'in', 'July', 'this', 'year', 'because', 'I', 'think', 'the', 'weather', 'will', 'be', 'nice', 'and', 'I', 'can', 'take', 'a', 'holiday', '.\n']
# ['S', 'I', 'would', 'like', 'to', 'use', 'a', 'tent', 'for', 'my', 'accommodation', '.\n']
# failed
# failed
# ['S', 'It', 'seems', 'to', 'be', 'exciting', '.\n']
# ['S', 'I', 'choose', 'swimming', 'and', 'painting', 'for', 'my', 'activities', 'while', 'I', 'am', 'at', 'the', 'Camp', '.\n']
# ['S', 'I', 'really', 'like', 'swimming', '.\n']
# failed
# ['S', 'It', 'was', 'such', 'a', 'good', 'time', '.\n']
# ['S', 'I', 'enjoy', 'painting', 'as', 'well', '.\n']
# ['S', 'My', 'mother', 'told', 'me', 'that', 'I', "'m", 'good', 'at', 'painting', '.\n']
# ['S', 'When', 'I', 'was', 'in', 'high', 'school', ',', 'I', 'won', 'second', 'prize', 'in', 'a', 'painting', 'competition', '.\n']
# failed
# ['S', 'Could', 'I', 'ask', 'you', 'some', 'questions', '?\n']
# failed
# failed
# ['S', 'I', 'look', 'forward', 'to', 'hearing', 'from', 'you', '.\n']
# ['S', 'Yours', 'sincerely', ',\n']
# ['S', 'Dear', 'Kim', ',\n']
# ['S', 'Thank', 'you', 'for', 'your', 'letter', '.\n']
# ['S', 'I', "'m", 'sorry', 'that', 'I', "'ve", 'taken', 'such', 'a', 'long', 'time', 'to', 'reply', 'your', 'letter', 'because', 'I', "'m", 'really', 'busy', 'and', 'I', 'have', 'to', 'study', 'harder', '.\n']
# ['S', 'I', "'m", 'taking', 'the', 'final', 'exam', 'next', 'month', '.\n']
# ['S', 'Lucky', 'me', '!\n']
# ['S', 'I', "'ve", 'got', 'some', 'great', 'news', 'to', 'tell', 'you', '.\n']
# failed
# ['S', 'I', 'really', 'enjoyed', 'helping', 'at', 'a', 'pop', 'concert', '.\n']
# ['S', 'As', 'you', 'know', ',', 'I', "'m", 'crazy', 'about', 'pop', 'music', '.\n']
# ['S', 'Before', 'the', 'concert', 'I', 'was', 'really', 'exciting', '.\n']
# failed
# ['S', 'It', 'was', 'such', 'a', 'big', 'concert', '.\n']
# failed
# failed
# ['S', 'First', ',', 'I', 'was', 'in', 'front', 'of', 'the', 'entrance', 'door', '.\n']
# ['S', 'I', 'had', 'to', 'check', 'tickets', '.\n']
# ['S', 'I', 'was', 'really', 'exciting', '.\n']
# failed
# failed
# ['S', 'I', 'could', 'see', 'lots', 'of', 'pop', 'stars', '.\n']
# failed
# ['S', 'I', 'was', 'really', 'busy', '.\n']
# failed
# failed
# ['S', 'It', 'was', 'really', 'busy', 'but', 'I', 'really', 'enjoyed', 'it', '.\n']
# failed
# ['S', 'I', 'had', 'to', 'be', 'more', 'patient', '.\n']
# failed
# failed
# ['S', 'I', "'d", 'better', 'close', 'now', '.\n']
# ['S', 'I', "'ve", 'got', 'lots', 'of', 'homework', 'to', 'do', '.\n']
# ['S', 'Take', 'care', 'of', 'yourself', 'and', 'I', 'look', 'forward', 'to', 'hearing', 'from', 'you', '.\n']
# ['S', 'Best', 'wishes', ',\n']
# ['S', 'Dear', 'Jane', 'Clark\n']
# ['S', 'Hello', '!\n']
# ['S', 'My', 'name', 'is', 'Yuna', 'Kimber', 'who', 'attended', 'this', 'annual', 'International', 'Arts', 'Festival', '.\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'I', 'expect', 'that', 'much', 'more', 'various', 'kinds', 'of', 'plays', 'and', 'films', 'will', 'be', 'on', 'next', 'year', '.\n']
# failed
# failed
# failed
# ['S', 'I', 'hope', 'it', 'will', 'be', 'helpful', 'and', 'useful', 'for', 'you', '.\n']
# ['S', 'Bye', 'for', 'now\n']
# ['S', 'Faithfully', 'yours\n']
# failed
# ['S', 'Their', 'parents', 'were', 'rich', ',', 'so', 'when', 'they', 'passed', 'away', 'they', 'left', 'a', 'lot', 'of', 'money', '.\n']
# failed
# failed
# failed
# failed
# ['S', 'But', ',', 'Nolbu', 'always', 'made', 'people', 'annoyed', ',', 'and', 'enjoyed', 'other', 'people', "'s", 'misfortune', '.\n']
# failed
# ['S', 'He', 'cured', 'the', 'bird', 'to', 'fly', 'with', 'love', ',', 'and', 'the', 'bird', 'was', 'able', 'to', 'fly', '.\n']
# ['S', 'The', 'following', 'year', ',', 'when', 'the', 'bird', 'returned', 'his', 'house', ',', 'he', 'gave', 'him', 'a', 'message', '.\n']
# failed
# ['S', 'Therefore', ',', 'Hungbu', 'became', 'much', 'richer', 'than', 'Nolbu', ',', 'and', 'he', 'lived', 'happily', 'with', 'the', 'money', 'helping', 'the', 'poor', '.\n']
# failed
# ['S', 'This', 'story', 'happened', 'a', 'long', 'time', 'ago', '.\n']
# ['S', 'Dear', 'sir', 'or', 'madam', ',\n']
# ['S', 'My', 'name', 'is', 'Molly', 'Menbrook', '.\n']
# ['S', 'I', 'have', 'seen', 'your', 'new', 'musical', ',', "'", 'Over', 'the', 'rainbow', "'", '.\n']
# ['S', 'I', 'am', 'sorry', 'but', 'I', 'must', 'admit', 'it', 'was', 'a', 'bit', 'disappointing', '.\n']
# ['S', 'I', 'bought', 'the', 'ticket', 'for', 'the', 'evening', 'performance', 'to', 'end', 'the', 'day', 'with', 'a', 'nice', 'musical', '.\n']
# ['S', 'But', 'the', 'time', 'was', "n't", 'kept', '.\n']
# ['S', 'I', 'had', 'to', 'wait', '45mins', 'to', 'get', 'in', '!\n']
# failed
# ['S', 'I', 'could', "n't", 'see', 'anyone', 'inside', 'either', '.\n']
# ['S', 'No', 'one', '.\n']
# failed
# ['S', 'The', 'show', 'was', 'OK', 'though', 'I', 'suggest', 'you', 'hire', 'different', 'actors', '.\n']
# ['S', 'I', 'think', 'Danny', 'Brook', 'does', "n't", 'suit', 'the', 'role', 'he', 'plays', 'in', 'this', 'musical', '...\n']
# ['S', 'Also', 'you', 'mentioned', 'a', 'discount', '.\n']
# ['S', 'For', 'tickets', '.\n']
# ['S', 'Well', 'no', ',', 'I', 'did', "n't", 'get', 'a', 'discount', '!\n']
# ['S', 'And', 'the', 'tickets', 'were', 'pretty', 'expensive', '...\n']
# failed
# ['S', 'Then', 'a', 'person', 'appeared', ',', 'walking', 'towards', 'the', 'door', 'to', 'the', 'kitchen', ',', 'I', 'guessed', '.\n']
# ['S', 'I', 'asked', 'him', 'why', 'the', 'restaurant', 'was', 'closed', '.\n']
# failed
# ['S', 'They', 'had', 'been', 'closed', 'for', '3', 'days', 'according', 'to', 'him', '.\n']
# ['S', 'So', 'you', 'see', 'my', 'point', '.\n']
# ['S', 'It', 'was', "n't", 'very', 'pleasant', '.\n']
# ['S', 'So', 'I', 'am', 'going', 'to', 'ask', 'for', 'a', 'refund', '...\n']
# failed
# ['S', 'Or', 'asking', 'you', 'for', 'too', 'much', '.\n']
# ['S', 'Reply', 'as', 'soon', 'as', 'possible', ',\n']
# ['S', 'best', 'regards', ',\n']
# ['S', 'I', 'think', 'the', 'clothes', 'in', 'future', 'will', 'be', 'similar', 'in', 'shape', 'as', 'the', 'clothes', 'that', 'exist', 'now', '.\n']
# ['S', 'Just', 'like', 'sweaters', ',', 'shoes', ',', 't', '-', 'shirts', 'etc', '...\n']
# ['S', 'But', 'maybe', 'not', '.\n']
# failed
# failed
# ['S', 'Maybe', 'silver', 'and', 'gold', ',', 'glittery', 'red', ',', 'purple', 'and', 'blue', '.\n']
# ['S', 'As', 'well', 'as', 'bright', 'yellow', ',', 'orange', 'and', 'green', '.\n']
# ['S', 'All', 'suitable', 'for', 'discos', '!\n']
# ['S', 'Shoes', 'will', 'be', 'high', 'heeled', 'and', 'modern', '.\n']
# failed
# ['S', 'Still', ',', 'comfortable', '.\n']
# ['S', 'I', 'think', 'they', "'ll", 'be', 'based', 'on', 'some', 'kind', 'of', 'space', 'theme', 'and', 'aliens', '.\n']
# ['S', 'But', 'I', 'think', 'I', 'prefer', 'the', 'clothes', 'now', '.\n']
# ['S', 'I', "'ll", 'stick', 'to', 'baggy', 't', '-', 'shirts', ',', 'jeans', ',', 'baseball', 'caps', 'and', 'trainers', '.\n']
# ['S', 'They', "'ll", 'do', 'for', 'me', 'instead', 'of', 'all', 'the', 'silvers', 'and', 'golds', '.\n']
# ['S', 'Al', 'the', 'spacy', 'theme', '.\n']
# ['S', 'I', 'think', 'I', "'ll", 'be', 'fine', 'in', 'the', 'clothes', 'we', 'have', 'now', '...\n']
# failed
# ['S', 'Though', 'some', 'people', 'may', 'fancy', 'the', 'glitter', 'and', 'the', 'spacy', 'feel', ',', 'I', 'do', "n't", 'like', 'it', 'and', 'I', 'hope', 'it', 'really', 'is', "n't", 'the', 'style', 'for', 'the', 'future', '.\n']
# ['S', 'It', "'s", 'just', 'not', 'my', 'cup', 'of', 'tea', '...\n']
# ['S', 'Dear', 'Mrs', 'Ryan', ',\n']
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'But', 'why', 'is', 'shopping', 'so', 'popular', 'and', 'loved', 'by', 'so', 'many', 'people', 'all', 'over', 'the', 'world', '?\n']
# failed
# ['S', 'The', 'verb', '"', 'have', '"', 'is', 'probably', 'the', 'most', 'used', 'and', 'loved', 'by', 'the', 'human', 'species', '.\n']
# ['S', 'We', 'are', 'always', 'trying', 'to', 'have', 'more', 'things', ',\n']
# failed
# failed
# failed
# failed
# failed
# failed
# ['S', 'We', 'still', 'look', 'at', 'what', 'people', 'look', 'like', 'and', 'not', 'at', 'what', 'they', 'really', 'are', '.\n']
# ['S', 'Dear', 'Mr.', 'Smith', ';\n']
# failed
# ['S', 'First', ',', 'it', 'did', "n't", 'start', 'at', '19.30', '.\n']
# ['S', 'It', 'started', 'at', '20.15', '.\n']
# ['S', 'We', 'had', 'to', 'wait', 'for', '45', 'minutes', '.\n']
# ['S', 'I', 'got', 'bored', '.\n']
# ['S', 'Not', 'only', 'me', 'but', 'also', 'the', 'others', 'got', 'bored', '.\n']
# failed
# ['S', 'But', 'it', 'was', 'not', 'Danny', 'Brock', ',', 'it', 'was', 'a', 'different', 'actor', '.\n']
# failed
# ['S', 'I', 'wanted', 'to', 'see', 'him', 'but', 'I', 'could', "n't", 'see', '.\n']
# ['S', 'This', 'was', 'very', 'disappointing', 'for', 'me', '.\n']
# ['S', 'When', 'I', 'was', 'buying', 'a', 'ticket', ',', 'there', 'was', 'no', 'discount', '.\n']
# failed
# ['S', 'I', 'paid', 'Â£20', 'to', 'the', 'cashier', '.\n']
# ['S', 'I', 'was', 'hungry', 'and', 'I', 'thought', 'I', 'could', 'eat', 'something', 'at', 'the', 'theatre', 'restaurant', 'after', 'the', 'show', '.\n']
# ['S', 'But', 'it', 'was', 'closed', 'without', 'any', 'reason', '.\n']
# ['S', 'It', 'was', 'very', 'rude', '.\n']
# ['S', 'For', 'this', ',', 'I', 'want', 'my', 'money', 'back', '.\n']
# failed
# failed
# ['S', 'Yours', 'sincerely', ',\n']
# ['S', 'TECHNOLOGICAL', 'ADVANTAGES\n']
# ['S', 'Technology', 'is', 'the', 'thing', 'that', 'makes', 'our', 'life', 'easy', '.\n']
# ['S', 'Technology', 'is', 'in', 'every', 'part', 'of', 'our', 'life', '.\n']
# ['S', 'We', 'use', 'cars', ',', 'trains', ',', 'ships', 'or', 'planes', 'when', 'we', 'want', 'to', 'go', 'somewhere', '.\n']
# failed
# failed
# failed
# failed
# failed
# ['S', 'It', 'takes', 'less', 'time', 'than', 'going', 'by', 'horse', '.\n']
# failed
# failed
# ['S', 'Not', 'only', 'as', 'a', 'hobby', '.\n']
# failed
# failed
# ['S', 'Sometimes', 'they', 'do', "n't", 'go', 'to', 'their', 'offices', '.\n']
# failed
# ['S', 'Computers', 'hold', 'them', 'in', 'their', 'memory', '.\n']
# failed
# ['S', 'But', 'it', 'has', 'also', 'bad', 'points', '.\n']
# ['S', 'For', 'example', ';', 'wars', '.\n']
# failed
# failed
# failed
# ['S', 'Dear', 'Sir', 'or', 'Madam', ',\n']
# failed
# failed
# failed
# ['S', 'Besides', ',', 'since', 'my', 'girlfriend', 'and', 'I', 'had', 'really', 'to', 'hurry', 'up', 'to', 'reach', 'the', 'theatre', 'on', 'time', 'we', 'had', "n't", 'had', 'any', 'dinner', ',', 'as', 'we', 'had', 'been', 'thinking', 'to', 'have', 'it', 'at', 'your', 'restaurant', '.\n']
# failed
# failed
# ['S', 'Yours', 'Faithfully\n']
# ['S', 'Unfortunately', ',', 'Pat', 'was', "n't", 'very', 'good', 'at', 'keeping', 'secrets', '.\n']
# failed
# failed
# ['S', 'I', 'could', 'actually', 'say', 'that', 'if', 'it', 'had', "n't", 'been', 'for', 'Mr.', 'White', 'she', 'would', 'have', 'never', 'passed', 'her', 'exam', 'to', 'enter', 'University', '.\n']
# failed
# ['S', 'One', 'day', 'while', 'she', 'was', 'walking', 'in', 'Central', 'Park', 'she', 'saw', 'a', 'man', 'and', 'a', 'young', 'girl', 'sitting', 'under', 'a', 'tree', '.\n']
# failed
# failed
# failed
# failed
# failed

# %% [markdown]
# ## Part 3: Creating a new file with errors suppressed

# %%
with open("/content/new_file.m2", "w+") as f: 
  for sent_idx in range(len(sentences)): 
    f.write(sentences[sent_idx])
    annot_idx = 0
    for annotation in annotations[sent_idx]: 
      if annot_idx not in errors_to_suppress[sent_idx]: 
        f.write(annotation)
      annot_idx += 1

    f.write("\n")
